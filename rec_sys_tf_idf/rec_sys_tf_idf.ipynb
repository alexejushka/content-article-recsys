# %%
import logging
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.sparse import coo_matrix
from implicit.als import AlternatingLeastSquares
from implicit.nearest_neighbours import bm25_weight
from catboost import CatBoostRanker, Pool
from sklearn.model_selection import train_test_split

# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
# %config InlineBackend.figure_format = 'retina'
pd.set_option('display.max_columns', 50)  # Показывать до 50 колонок
pd.set_option('display.max_colwidth', 100)  # Показывать до 50 колонок


data = pd.read_excel("../cuprum_3.xlsx", sheet_name="Лист4") #cuprum/Лист4/Лист2/Лист1
data.rename(columns={"пол":"gender", "возраст":"age"}, inplace=True)
data = data[data['action_type'] == 'CLICKED']
#data = data[data['tags'] != 'Секс']
data.drop(columns=["esb_ehr_id","patientnet_ehr_id", "medialog_ehr_id","action_type"], inplace=True)
data


# оставляем только тех пользователей, у которых есть не слишком много и не слишком мало взаимодействий
def filter_for_iteration_range(df_raw, min=4, max=50):
    interaction_counts = df_raw.groupby('ehr_id')['article_id'].count()
    users_in_range = set(interaction_counts[(interaction_counts >= min) & (interaction_counts <= max)].index)
    df_filtered = data[data['ehr_id'].isin(users_in_range)]
    return df_filtered

# негерируем негативные сэмлы для работы модели
def generate_negative_samples(df, all_articles, n_negatives=3):
    negatives = []

    for user_id, group in df.groupby('ehr_id'):
        clicked = set(group['article_id'])
        not_clicked = list(all_articles - clicked)
        sampled = np.random.choice(not_clicked, size=n_negatives, replace=False)

        for art in sampled:
            negatives.append({
                "ehr_id": user_id,
                "article_id": art,
                "label": 0
            })

    return pd.DataFrame(negatives)

data = filter_for_iteration_range(data)
data
# Out:
#             id                article_id   ehr_id created_at  gender  age
# 44     3753815  60258f50e3c78375686c0c51  1132756 2023-07-01       1   48  \
# 51     3754559  62e24b5be4ff39162208fd33  1169819 2023-07-01       1   31
# 52     3754575  62e24b5be4ff39162208fd33  1169819 2023-07-01       1   31
# 53     3754576  62e24610a9c9279df00b8673  1169819 2023-07-01       1   31
# 54     3754581  62e0f1c5df18e4454c047292  1169819 2023-07-01       1   31
# ...        ...                       ...      ...        ...     ...  ...
# 30815  9603468  622b44d60e7b1e54fe5e5342   272451 2024-07-30       1   52
# 30816  9603700  6218dd9140e8460b6d1e326b    57714 2024-07-30       1   58
# 30817  9603737  617bfecbd4f2793d703e2db2  1145846 2024-07-30       1   36
# 30818  9603851  63e10773dbd23b1bff0b7002   263328 2024-07-30       1   31
# 30823  9606297  64d26487404f426d590b9d32  1420298 2024-07-30       1   40
#
#         birthday
# 44    1976-12-22  \
# 51    1993-07-08
# 52    1993-07-08
# 53    1993-07-08
# 54    1993-07-08
# ...          ...
# 30815 1973-01-09
# 30816 1966-06-25
# 30817 1989-05-11
# 30818 1993-09-13
# 30823 1985-01-28
#
#                                                                                           title
# 44                                                              ​Как понять, что у вас паразиты  \
# 51                                  Как скрининг помог вовремя обнаружить дисплазию шейки матки
# 52                                  Как скрининг помог вовремя обнаружить дисплазию шейки матки
# 53                            Что почитать: «Мальчик, который не переставал расти» Эдвина Кёрка
# 54     «В суете нашей жизни некогда подумать о собственном здоровье»: как предотвратить инсульт
# ...                                                                                         ...
# 30815                                                                     Cкрининг на рак груди
# 30816                                     Если хорошенько потрястись, это поможет снять стресс?
# 30817                              Одноразовые электронные сигареты опаснее, чем обычные вейпы?
# 30818                                         Плесень на орехах и кукурузе вызывает рак печени?
# 30823                                                                   Обрезание — это больно?
#
#                                                                              url
# 44               https://cuprum.media/science-answers/find-parasites?from=avaapp  \
# 51                https://cuprum.media/interview/neoplasia-screening?from=avaapp
# 52                https://cuprum.media/interview/neoplasia-screening?from=avaapp
# 53     https://cuprum.media/razbor/the-boy-who-never-stopped-growing?from=avaapp
# 54                  https://cuprum.media/interview/stroke-prevention?from=avaapp
# ...                                                                          ...
# 30815    https://cuprum.media/spravochnik/screening-breast-cancer-sp?from=avaapp
# 30816                https://cuprum.media/proverka-sluha/shaking-off?from=avaapp
# 30817                        https://cuprum.media/razbor/vape-nation?from=avaapp
# 30818           https://cuprum.media/science-answers/nuts-and-cancer?from=avaapp
# 30823                         https://cuprum.media/razbor/obrezaniye?from=avaapp
#
#          views published_date    formats                          tags
# 44      5779.0     2021-02-11   longread                             0  \
# 51      4580.0     2022-07-28  interview  Диагностика,Женское здоровье
# 52      4580.0     2022-07-28  interview  Диагностика,Женское здоровье
# 53       347.0     2022-07-28   longread                         Книги
# 54       892.0     2022-07-27  interview                   Диагностика
# ...        ...            ...        ...                           ...
# 30815   1072.0     2022-03-11  shortread                      Скрининг
# 30816   6086.0     2022-02-25   longread                    Ментальное
# 30817  11716.0     2021-10-29   longread                 Горло,Гаджеты
# 30818   1455.0     2023-02-06   longread        Еда,Онкология,Патогены
# 30823  26681.0     2023-08-08   longread             Деликатный вопрос
#
#             rubric_title
# 44     Ответили по науке
# 51              Интервью
# 52              Интервью
# 53                Разбор
# 54              Интервью
# ...                  ...
# 30815         Справочник
# 30816     Проверка слуха
# 30817             Разбор
# 30818  Ответили по науке
# 30823             Разбор
#
# [7482 rows x 14 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

class ContentRecommenderSystem:
    """
    Контентная рекомендательная система на основе TF-IDF и косинусного сходства
    """
    
    def __init__(self, df):
        """
        Инициализация системы рекомендаций
        
        Parameters:
        df: DataFrame с данными о статьях и пользователях
        """
        self.df = df.copy()
        self.tfidf_matrix = None
        self.article_features = None
        self.prepare_data()
        
    def prepare_data(self):
        """Подготовка данных для рекомендательной системы"""
        
        # Удаляем дубликаты статей для создания каталога
        self.articles = self.df[['article_id', 'title', 'tags', 'rubric_title', 'views', 'published_date']].drop_duplicates('article_id')
        
        # Заполняем пропущенные значения
        self.articles['tags'] = self.articles['tags'].fillna('')
        self.articles['rubric_title'] = self.articles['rubric_title'].fillna('')
        self.articles['title'] = self.articles['title'].fillna('')
        
        # Создаем комбинированное текстовое представление статьи
        # Даем больший вес заголовку, повторяя его
        self.articles['content'] = (
            self.articles['title'] + ' ' + 
            self.articles['title'] + ' ' +  # удваиваем заголовок для большего веса
            self.articles['tags'].astype(str).str.replace(',', ' ') + ' ' + 
            self.articles['rubric_title']
        )
        
        # Создаем TF-IDF матрицу
        self.vectorizer = TfidfVectorizer(
            max_features=1000,
            ngram_range=(1, 2),  # используем униграммы и биграммы
            min_df=2,
            max_df=0.8,
            token_pattern=r'[а-яА-Яa-zA-Z]+' # учитываем и русские, и английские слова
        )
        
        self.tfidf_matrix = self.vectorizer.fit_transform(self.articles['content'])
        
        # Добавляем нормализованную популярность как дополнительный признак
        scaler = MinMaxScaler()
        popularity_scores = scaler.fit_transform(self.articles[['views']].fillna(0))
        
        # Комбинируем TF-IDF с популярностью (90% контент, 10% популярность)
        self.content_similarity = cosine_similarity(self.tfidf_matrix)
        self.final_similarity = 0.9 * self.content_similarity + 0.1 * cosine_similarity(popularity_scores)
        
        print(f"Подготовлено {len(self.articles)} уникальных статей")
        print(f"Размер TF-IDF матрицы: {self.tfidf_matrix.shape}")
        
    def get_user_history(self, user_id):
        """
        Получение истории просмотров пользователя
        
        Parameters:
        user_id: ID пользователя (ehr_id)
        
        Returns:
        list: список ID просмотренных статей
        """
        user_articles = self.df[self.df['ehr_id'] == user_id]['article_id'].unique()
        return user_articles
    
    def get_similar_articles(self, article_id, top_n=10):
        """
        Получение похожих статей для данной статьи
        
        Parameters:
        article_id: ID статьи
        top_n: количество рекомендаций
        
        Returns:
        DataFrame с рекомендациями
        """
        if article_id not in self.articles['article_id'].values:
            return pd.DataFrame()
        
        # Находим индекс статьи
        idx = self.articles[self.articles['article_id'] == article_id].index[0]
        article_idx = self.articles.index.get_loc(idx)
        
        # Получаем похожие статьи
        sim_scores = list(enumerate(self.final_similarity[article_idx]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        
        # Исключаем саму статью (первая в списке)
        sim_scores = sim_scores[1:top_n+1]
        
        # Получаем индексы и scores
        article_indices = [i[0] for i in sim_scores]
        similarity_scores = [i[1] for i in sim_scores]
        
        # Создаем DataFrame с результатами
        recommendations = self.articles.iloc[article_indices][['article_id', 'title', 'tags', 'rubric_title']].copy()
        recommendations['similarity_score'] = similarity_scores
        
        return recommendations
    
    def recommend_for_user(self, user_id, top_n=10, method='weighted'):
        """
        Рекомендации для пользователя на основе истории просмотров
        
        Parameters:
        user_id: ID пользователя (ehr_id)
        top_n: количество рекомендаций
        method: метод агрегации ('weighted' - взвешенный, 'max' - максимум, 'avg' - среднее)
        
        Returns:
        DataFrame с рекомендациями
        """
        # Получаем историю пользователя
        user_history = self.get_user_history(user_id)
        
        if len(user_history) == 0:
            print(f"Пользователь {user_id} не найден или нет истории просмотров")
            return self.get_popular_articles(top_n)
        
        print(f"Пользователь {user_id} просмотрел {len(user_history)} статей")
        
        # Получаем все статьи для рекомендаций
        all_article_ids = self.articles['article_id'].values
        
        # Исключаем уже просмотренные
        candidate_articles = [a for a in all_article_ids if a not in user_history]
        
        # Словарь для хранения scores
        article_scores = {}
        
        # Для каждой просмотренной статьи находим похожие
        for viewed_article in user_history:
            if viewed_article not in self.articles['article_id'].values:
                continue
                
            # Находим индекс просмотренной статьи
            idx = self.articles[self.articles['article_id'] == viewed_article].index[0]
            article_idx = self.articles.index.get_loc(idx)
            
            # Получаем схожесть со всеми статьями
            similarities = self.final_similarity[article_idx]
            
            # Обновляем scores для кандидатов
            for i, candidate_id in enumerate(self.articles['article_id'].values):
                if candidate_id in candidate_articles:
                    if candidate_id not in article_scores:
                        article_scores[candidate_id] = []
                    article_scores[candidate_id].append(similarities[i])
        
        # Агрегируем scores в зависимости от метода
        final_scores = {}
        for article_id, scores in article_scores.items():
            if method == 'weighted':
                # Взвешенный score с учетом свежести просмотров
                weights = np.linspace(0.5, 1.0, len(scores))  # новые просмотры важнее
                final_scores[article_id] = np.average(scores, weights=weights[-len(scores):])
            elif method == 'max':
                final_scores[article_id] = max(scores)
            else:  # avg
                final_scores[article_id] = np.mean(scores)
        
        # Сортируем по score
        sorted_articles = sorted(final_scores.items(), key=lambda x: x[1], reverse=True)[:top_n]
        
        # Создаем DataFrame с рекомендациями
        rec_ids = [a[0] for a in sorted_articles]
        rec_scores = [a[1] for a in sorted_articles]
        
        recommendations = self.articles[self.articles['article_id'].isin(rec_ids)][
            ['article_id', 'title', 'tags', 'rubric_title', 'views']
        ].copy()
        
        # Добавляем scores
        recommendations['recommendation_score'] = recommendations['article_id'].map(
            dict(zip(rec_ids, rec_scores))
        )
        
        # Сортируем по score
        recommendations = recommendations.sort_values('recommendation_score', ascending=False)
        
        return recommendations
    
    def get_popular_articles(self, top_n=10):
        """
        Получение самых популярных статей (fallback для холодного старта)
        
        Parameters:
        top_n: количество статей
        
        Returns:
        DataFrame с популярными статьями
        """
        return self.articles.nlargest(top_n, 'views')[['article_id', 'title', 'tags', 'rubric_title', 'views']]
    
    def evaluate_diversity(self, recommendations):
        """
        Оценка разнообразия рекомендаций
        
        Parameters:
        recommendations: DataFrame с рекомендациями
        
        Returns:
        dict: метрики разнообразия
        """
        if len(recommendations) == 0:
            return {}
        
        # Уникальные рубрики
        unique_rubrics = recommendations['rubric_title'].nunique()
        
        # Среднее попарное расстояние между рекомендациями
        rec_indices = []
        for article_id in recommendations['article_id'].values:
            if article_id in self.articles['article_id'].values:
                idx = self.articles[self.articles['article_id'] == article_id].index[0]
                rec_indices.append(self.articles.index.get_loc(idx))
        
        if len(rec_indices) > 1:
            avg_distance = 0
            count = 0
            for i in range(len(rec_indices)):
                for j in range(i+1, len(rec_indices)):
                    avg_distance += 1 - self.content_similarity[rec_indices[i], rec_indices[j]]
                    count += 1
            avg_distance = avg_distance / count if count > 0 else 0
        else:
            avg_distance = 0
        
        return {
            'unique_rubrics': unique_rubrics,
            'rubrics_ratio': unique_rubrics / len(recommendations),
            'avg_content_distance': avg_distance
        }


# Пример использования
def demo_recommendations(df):
    """
    Демонстрация работы рекомендательной системы
    """
    # Создаем систему рекомендаций
    recommender = ContentRecommenderSystem(df)
    
    # Выбираем случайного пользователя с историей
    users_with_history = df.groupby('ehr_id').size()
    active_users = users_with_history[users_with_history >= 5].index.tolist()
    
    if active_users:
        sample_user = np.random.choice(active_users)
        
        print(f"\n{'='*50}")
        print(f"Рекомендации для пользователя {sample_user}")
        print(f"{'='*50}\n")
        
        # История пользователя
        user_history = recommender.get_user_history(sample_user)
        history_df = df[df['ehr_id'] == sample_user][['article_id', 'title']].drop_duplicates()
        
        print("История просмотров пользователя:")
        for _, row in history_df.head(5).iterrows():
            print(f"- {row['title'][:80]}...")
        
        # Получаем рекомендации
        recommendations = recommender.recommend_for_user(sample_user, top_n=10)
        
        print(f"\n{'='*50}")
        print("Топ-10 рекомендаций:")
        print(f"{'='*50}\n")
        
        for i, row in recommendations.iterrows():
            print(f"{len(recommendations) - recommendations.index.get_loc(i)}. {row['title'][:70]}...")
            print(f"   Рубрика: {row['rubric_title']}, Score: {row['recommendation_score']:.3f}")
            print()
        
        # Оценка разнообразия
        diversity = recommender.evaluate_diversity(recommendations)
        print(f"\n{'='*50}")
        print("Метрики разнообразия рекомендаций:")
        print(f"{'='*50}")
        print(f"Уникальных рубрик: {diversity['unique_rubrics']}")
        print(f"Доля уникальных рубрик: {diversity['rubrics_ratio']:.2%}")
        print(f"Среднее расстояние между рекомендациями: {diversity['avg_content_distance']:.3f}")
    
    return recommender


# Если у вас уже есть загруженный DataFrame df, используйте:
# recommender = ContentRecommenderSystem(df)
# recommendations = recommender.recommend_for_user(user_id=1169819, top_n=10)
# print(recommendations)

# %%
def generate_recommendations_for_all(df, output_path="recommendations.csv", top_n=10):
    # Инициализируем систему
    recommender = ContentRecommenderSystem(df)
    
    # Получаем список всех пользователей
    users = df['ehr_id'].unique()
    #users = df['ehr_id']
    #users = users.head(10)
    
    all_recs = []

    for user_id in users:
        recs = recommender.recommend_for_user(user_id, top_n=top_n)
        
        if recs is not None and len(recs) > 0:
            recs = recs.copy()
            recs['ehr_id'] = user_id
            all_recs.append(recs[['ehr_id', 'article_id', 'title', 'rubric_title', 'recommendation_score']])
    
    # Объединяем все рекомендации
    result_df = pd.concat(all_recs, ignore_index=True)
    
    # Сохраняем в CSV
    result_df.to_csv(output_path, index=False, encoding="utf-8")
    print(f"Сохранено {len(result_df)} рекомендаций для {len(users)} пользователей в файл {output_path}")

    return result_df

# %%
recs_df = generate_recommendations_for_all(data, "user_recommendations_all.csv", top_n=20)
# Out:
# Подготовлено 2954 уникальных статей
# Размер TF-IDF матрицы: (2954, 1000)
# Пользователь 1132756 просмотрел 5 статей
# Пользователь 1169819 просмотрел 21 статей
# Пользователь 966281 просмотрел 8 статей
# Пользователь 780606 просмотрел 8 статей
# Пользователь 232858 просмотрел 6 статей
# Пользователь 1153297 просмотрел 4 статей
# Пользователь 991913 просмотрел 12 статей
# Пользователь 1241112 просмотрел 4 статей
# Пользователь 1173385 просмотрел 10 статей
# Пользователь 1273528 просмотрел 5 статей
# Пользователь 1278017 просмотрел 5 статей
# Пользователь 234386 просмотрел 9 статей
# Пользователь 390291 просмотрел 5 статей
# Пользователь 933336 просмотрел 11 статей
# Пользователь 1031865 просмотрел 8 статей
# Пользователь 541168 просмотрел 4 статей
# Пользователь 511237 просмотрел 5 статей
# Пользователь 381190 просмотрел 5 статей
# Пользователь 1082313 просмотрел 5 статей
# Пользователь 1278693 просмотрел 8 статей
# Пользователь 1292915 просмотрел 17 статей
# Пользователь 439638 просмотрел 4 статей
# Пользователь 1244233 просмотрел 4 статей
# Пользователь 1252522 просмотрел 4 статей
# Пользователь 755017 просмотрел 17 статей
# Пользователь 1210473 просмотрел 4 статей
# Пользователь 892250 просмотрел 6 статей
# Пользователь 482814 просмотрел 5 статей
# Пользователь 107818 просмотрел 5 статей
# Пользователь 73208 просмотрел 10 статей
# Пользователь 1296752 просмотрел 4 статей
# Пользователь 1264232 просмотрел 9 статей
# Пользователь 1186627 просмотрел 15 статей
# Пользователь 697996 просмотрел 5 статей
# Пользователь 1100185 просмотрел 25 статей
# Пользователь 1293592 просмотрел 6 статей
# Пользователь 666170 просмотрел 20 статей
# Пользователь 1258117 просмотрел 4 статей
# Пользователь 1264203 просмотрел 6 статей
# Пользователь 1031385 просмотрел 3 статей
# Пользователь 566038 просмотрел 7 статей
# Пользователь 1270409 просмотрел 4 статей
# Пользователь 1279625 просмотрел 7 статей
# Пользователь 573819 просмотрел 4 статей
# Пользователь 1289932 просмотрел 4 статей
# Пользователь 1296656 просмотрел 19 статей
# Пользователь 1294925 просмотрел 6 статей
# Пользователь 1043051 просмотрел 3 статей
# Пользователь 1295000 просмотрел 5 статей
# Пользователь 1248589 просмотрел 4 статей
# Пользователь 1296543 просмотрел 4 статей
# Пользователь 1168577 просмотрел 5 статей
# Пользователь 1294811 просмотрел 6 статей
# Пользователь 1298917 просмотрел 8 статей
# Пользователь 134204 просмотрел 7 статей
# Пользователь 802068 просмотрел 6 статей
# Пользователь 466174 просмотрел 3 статей
# Пользователь 1298916 просмотрел 5 статей
# Пользователь 1295001 просмотрел 6 статей
# Пользователь 1298947 просмотрел 7 статей
# Пользователь 1013372 просмотрел 4 статей
# Пользователь 1110957 просмотрел 8 статей
# Пользователь 1298054 просмотрел 4 статей
# Пользователь 939712 просмотрел 7 статей
# Пользователь 1295369 просмотрел 6 статей
# Пользователь 1163771 просмотрел 7 статей
# Пользователь 1278381 просмотрел 5 статей
# Пользователь 892849 просмотрел 4 статей
# Пользователь 1298413 просмотрел 4 статей
# Пользователь 1291940 просмотрел 15 статей
# Пользователь 935649 просмотрел 4 статей
# Пользователь 550190 просмотрел 4 статей
# Пользователь 1241207 просмотрел 19 статей
# Пользователь 1195577 просмотрел 7 статей
# Пользователь 446556 просмотрел 4 статей
# Пользователь 1256736 просмотрел 9 статей
# Пользователь 1281793 просмотрел 16 статей
# Пользователь 1299032 просмотрел 4 статей
# Пользователь 1287625 просмотрел 4 статей
# Пользователь 1123825 просмотрел 13 статей
# Пользователь 212162 просмотрел 4 статей
# Пользователь 1262674 просмотрел 16 статей
# Пользователь 1184433 просмотрел 5 статей
# Пользователь 1118201 просмотрел 4 статей
# Пользователь 1297627 просмотрел 12 статей
# Пользователь 882313 просмотрел 5 статей
# Пользователь 569398 просмотрел 4 статей
# Пользователь 418983 просмотрел 8 статей
# Пользователь 1280221 просмотрел 8 статей
# Пользователь 929691 просмотрел 6 статей
# Пользователь 283394 просмотрел 6 статей
# Пользователь 40321 просмотрел 8 статей
# Пользователь 1299759 просмотрел 7 статей
# Пользователь 1161544 просмотрел 5 статей
# Пользователь 270216 просмотрел 8 статей
# Пользователь 188432 просмотрел 7 статей
# Пользователь 1286922 просмотрел 12 статей
# Пользователь 1223881 просмотрел 4 статей
# Пользователь 315739 просмотрел 6 статей
# Пользователь 791385 просмотрел 4 статей
# Пользователь 1299209 просмотрел 4 статей
# Пользователь 1280218 просмотрел 11 статей
# Пользователь 1192192 просмотрел 3 статей
# Пользователь 350674 просмотрел 7 статей
# Пользователь 361021 просмотрел 4 статей
# Пользователь 1253652 просмотрел 7 статей
# Пользователь 1225955 просмотрел 10 статей
# Пользователь 1299164 просмотрел 20 статей
# Пользователь 23102 просмотрел 4 статей
# Пользователь 302674 просмотрел 4 статей
# Пользователь 1281250 просмотрел 8 статей
# Пользователь 1300254 просмотрел 4 статей
# Пользователь 1119724 просмотрел 6 статей
# Пользователь 1203301 просмотрел 7 статей
# Пользователь 965530 просмотрел 4 статей
# Пользователь 1272127 просмотрел 4 статей
# Пользователь 1144698 просмотрел 4 статей
# Пользователь 31218 просмотрел 7 статей
# Пользователь 1265368 просмотрел 4 статей
# Пользователь 1245241 просмотрел 5 статей
# Пользователь 439412 просмотрел 4 статей
# Пользователь 1274024 просмотрел 5 статей
# Пользователь 1300094 просмотрел 7 статей
# Пользователь 1029903 просмотрел 19 статей
# Пользователь 431658 просмотрел 3 статей
# Пользователь 283271 просмотрел 4 статей
# Пользователь 649332 просмотрел 7 статей
# Пользователь 1273697 просмотрел 5 статей
# Пользователь 529083 просмотрел 4 статей
# Пользователь 834503 просмотрел 7 статей
# Пользователь 732329 просмотрел 8 статей
# Пользователь 906872 просмотрел 7 статей
# Пользователь 1297906 просмотрел 6 статей
# Пользователь 879621 просмотрел 6 статей
# Пользователь 1264030 просмотрел 5 статей
# Пользователь 1219896 просмотрел 12 статей
# Пользователь 1277889 просмотрел 5 статей
# Пользователь 1269390 просмотрел 2 статей
# Пользователь 348166 просмотрел 4 статей
# Пользователь 248179 просмотрел 11 статей
# Пользователь 1249595 просмотрел 8 статей
# Пользователь 533901 просмотрел 4 статей
# Пользователь 888522 просмотрел 4 статей
# Пользователь 1208068 просмотрел 4 статей
# Пользователь 1277933 просмотрел 12 статей
# Пользователь 1270367 просмотрел 6 статей
# Пользователь 1296561 просмотрел 4 статей
# Пользователь 1286986 просмотрел 4 статей
# Пользователь 132782 просмотрел 4 статей
# Пользователь 1290272 просмотрел 6 статей
# Пользователь 1161933 просмотрел 5 статей
# Пользователь 1299901 просмотрел 4 статей
# Пользователь 1301760 просмотрел 8 статей
# Пользователь 1301745 просмотрел 33 статей
# Пользователь 628596 просмотрел 16 статей
# Пользователь 1301683 просмотрел 8 статей
# Пользователь 1071565 просмотрел 4 статей
# Пользователь 726822 просмотрел 4 статей
# Пользователь 505146 просмотрел 7 статей
# Пользователь 1300425 просмотрел 4 статей
# Пользователь 998449 просмотрел 10 статей
# Пользователь 1301163 просмотрел 4 статей
# Пользователь 1062026 просмотрел 4 статей
# Пользователь 1100221 просмотрел 8 статей
# Пользователь 1114850 просмотрел 7 статей
# Пользователь 443566 просмотрел 5 статей
# Пользователь 1172470 просмотрел 8 статей
# Пользователь 1262259 просмотрел 7 статей
# Пользователь 1302061 просмотрел 7 статей
# Пользователь 379104 просмотрел 4 статей
# Пользователь 1092142 просмотрел 20 статей
# Пользователь 1284334 просмотрел 5 статей
# Пользователь 1212719 просмотрел 9 статей
# Пользователь 789806 просмотрел 5 статей
# Пользователь 1186923 просмотрел 6 статей
# Пользователь 1282300 просмотрел 4 статей
# Пользователь 1275860 просмотрел 8 статей
# Пользователь 791911 просмотрел 4 статей
# Пользователь 499899 просмотрел 7 статей
# Пользователь 1246715 просмотрел 4 статей
# Пользователь 1300509 просмотрел 4 статей
# Пользователь 914968 просмотрел 4 статей
# Пользователь 401241 просмотрел 7 статей
# Пользователь 530597 просмотрел 10 статей
# Пользователь 489811 просмотрел 9 статей
# Пользователь 1292509 просмотрел 6 статей
# Пользователь 291689 просмотрел 30 статей
# Пользователь 426026 просмотрел 4 статей
# Пользователь 166080 просмотрел 4 статей
# Пользователь 1022718 просмотрел 4 статей
# Пользователь 491234 просмотрел 6 статей
# Пользователь 1276205 просмотрел 15 статей
# Пользователь 39769 просмотрел 4 статей
# Пользователь 1272030 просмотрел 6 статей
# Пользователь 93303 просмотрел 3 статей
# Пользователь 1299743 просмотрел 4 статей
# Пользователь 1304158 просмотрел 4 статей
# Пользователь 1304244 просмотрел 5 статей
# Пользователь 441334 просмотрел 2 статей
# Пользователь 337720 просмотрел 7 статей
# Пользователь 1304388 просмотрел 4 статей
# Пользователь 1278484 просмотрел 14 статей
# Пользователь 173874 просмотрел 1 статей
# Пользователь 1299855 просмотрел 4 статей
# Пользователь 1254985 просмотрел 11 статей
# Пользователь 1303998 просмотрел 4 статей
# Пользователь 1191355 просмотрел 5 статей
# Пользователь 1286520 просмотрел 9 статей
# Пользователь 1304521 просмотрел 11 статей
# Пользователь 1004625 просмотрел 4 статей
# Пользователь 1259847 просмотрел 2 статей
# Пользователь 597197 просмотрел 4 статей
# Пользователь 1027514 просмотрел 5 статей
# Пользователь 1304706 просмотрел 8 статей
# Пользователь 110967 просмотрел 4 статей
# Пользователь 1259518 просмотрел 9 статей
# Пользователь 1304691 просмотрел 5 статей
# Пользователь 1300895 просмотрел 5 статей
# Пользователь 1176973 просмотрел 6 статей
# Пользователь 1304559 просмотрел 6 статей
# Пользователь 263328 просмотрел 4 статей
# Пользователь 1169073 просмотрел 6 статей
# Пользователь 18042 просмотрел 8 статей
# Пользователь 730892 просмотрел 4 статей
# Пользователь 998094 просмотрел 5 статей
# Пользователь 1220462 просмотрел 5 статей
# Пользователь 319401 просмотрел 4 статей
# Пользователь 901112 просмотрел 5 статей
# Пользователь 1111223 просмотрел 4 статей
# Пользователь 140348 просмотрел 8 статей
# Пользователь 1003540 просмотрел 5 статей
# Пользователь 508577 просмотрел 8 статей
# Пользователь 666127 просмотрел 7 статей
# Пользователь 1304417 просмотрел 4 статей
# Пользователь 1301024 просмотрел 4 статей
# Пользователь 1053466 просмотрел 4 статей
# Пользователь 1305902 просмотрел 4 статей
# Пользователь 117054 просмотрел 4 статей
# Пользователь 1306098 просмотрел 6 статей
# Пользователь 1303176 просмотрел 6 статей
# Пользователь 1306283 просмотрел 8 статей
# Пользователь 1306278 просмотрел 6 статей
# Пользователь 1306593 просмотрел 4 статей
# Пользователь 1263916 просмотрел 20 статей
# Пользователь 709852 просмотрел 6 статей
# Пользователь 811717 просмотрел 6 статей
# Пользователь 369968 просмотрел 7 статей
# Пользователь 1201336 просмотрел 11 статей
# Пользователь 1025154 просмотрел 5 статей
# Пользователь 1306282 просмотрел 6 статей
# Пользователь 1064495 просмотрел 5 статей
# Пользователь 973099 просмотрел 4 статей
# Пользователь 562354 просмотрел 5 статей
# Пользователь 1306868 просмотрел 10 статей
# Пользователь 102822 просмотрел 7 статей
# Пользователь 549394 просмотрел 5 статей
# Пользователь 729241 просмотрел 5 статей
# Пользователь 823060 просмотрел 4 статей
# Пользователь 1229914 просмотрел 7 статей
# Пользователь 566756 просмотрел 4 статей
# Пользователь 773550 просмотрел 4 статей
# Пользователь 785817 просмотрел 4 статей
# Пользователь 1294172 просмотрел 8 статей
# Пользователь 1307581 просмотрел 4 статей
# Пользователь 544637 просмотрел 5 статей
# Пользователь 1082761 просмотрел 4 статей
# Пользователь 1285399 просмотрел 6 статей
# Пользователь 1260795 просмотрел 15 статей
# Пользователь 1203865 просмотрел 4 статей
# Пользователь 33123 просмотрел 4 статей
# Пользователь 1308633 просмотрел 4 статей
# Пользователь 829649 просмотрел 3 статей
# Пользователь 170176 просмотрел 4 статей
# Пользователь 877442 просмотрел 5 статей
# Пользователь 1308871 просмотрел 4 статей
# Пользователь 476238 просмотрел 5 статей
# Пользователь 1308874 просмотрел 4 статей
# Пользователь 275199 просмотрел 8 статей
# Пользователь 1299229 просмотрел 12 статей
# Пользователь 1072957 просмотрел 9 статей
# Пользователь 1132518 просмотрел 6 статей
# Пользователь 1158184 просмотрел 5 статей
# Пользователь 57714 просмотрел 28 статей
# Пользователь 1309674 просмотрел 2 статей
# Пользователь 777889 просмотрел 4 статей
# Пользователь 1243012 просмотрел 4 статей
# Пользователь 670374 просмотрел 5 статей
# Пользователь 891176 просмотрел 4 статей
# Пользователь 1309959 просмотрел 6 статей
# Пользователь 1209278 просмотрел 6 статей
# Пользователь 985906 просмотрел 4 статей
# Пользователь 288194 просмотрел 7 статей
# Пользователь 126691 просмотрел 4 статей
# Пользователь 1167902 просмотрел 6 статей
# Пользователь 1157039 просмотрел 6 статей
# Пользователь 272140 просмотрел 4 статей
# Пользователь 662858 просмотрел 5 статей
# Пользователь 190243 просмотрел 5 статей
# Пользователь 1197287 просмотрел 5 статей
# Пользователь 1266953 просмотрел 10 статей
# Пользователь 1102423 просмотрел 7 статей
# Пользователь 1271363 просмотрел 7 статей
# Пользователь 256458 просмотрел 32 статей
# Пользователь 1243053 просмотрел 4 статей
# Пользователь 301610 просмотрел 5 статей
# Пользователь 1287738 просмотрел 8 статей
# Пользователь 813965 просмотрел 4 статей
# Пользователь 1248091 просмотрел 5 статей
# Пользователь 1230766 просмотрел 4 статей
# Пользователь 1053921 просмотрел 4 статей
# Пользователь 1276229 просмотрел 4 статей
# Пользователь 1027201 просмотрел 7 статей
# Пользователь 1299860 просмотрел 7 статей
# Пользователь 1202789 просмотрел 3 статей
# Пользователь 1267605 просмотрел 17 статей
# Пользователь 1063935 просмотрел 5 статей
# Пользователь 650279 просмотрел 3 статей
# Пользователь 734626 просмотрел 4 статей
# Пользователь 1300285 просмотрел 7 статей
# Пользователь 792352 просмотрел 6 статей
# Пользователь 175739 просмотрел 6 статей
# Пользователь 786699 просмотрел 7 статей
# Пользователь 747279 просмотрел 4 статей
# Пользователь 828708 просмотрел 4 статей
# Пользователь 1309992 просмотрел 6 статей
# Пользователь 1309969 просмотрел 5 статей
# Пользователь 1122712 просмотрел 6 статей
# Пользователь 1311785 просмотрел 11 статей
# Пользователь 881190 просмотрел 12 статей
# Пользователь 1308308 просмотрел 11 статей
# Пользователь 272353 просмотрел 5 статей
# Пользователь 247352 просмотрел 6 статей
# Пользователь 163489 просмотрел 4 статей
# Пользователь 1049537 просмотрел 6 статей
# Пользователь 1311557 просмотрел 4 статей
# Пользователь 1312046 просмотрел 4 статей
# Пользователь 1143566 просмотрел 4 статей
# Пользователь 158329 просмотрел 9 статей
# Пользователь 742849 просмотрел 4 статей
# Пользователь 1263837 просмотрел 7 статей
# Пользователь 1139860 просмотрел 5 статей
# Пользователь 1312472 просмотрел 3 статей
# Пользователь 1265789 просмотрел 4 статей
# Пользователь 279019 просмотрел 3 статей
# Пользователь 278914 просмотрел 9 статей
# Пользователь 916770 просмотрел 4 статей
# Пользователь 118915 просмотрел 5 статей
# Пользователь 1242188 просмотрел 4 статей
# Пользователь 816605 просмотрел 4 статей
# Пользователь 641012 просмотрел 4 статей
# Пользователь 1134919 просмотрел 6 статей
# Пользователь 1313232 просмотрел 6 статей
# Пользователь 141820 просмотрел 6 статей
# Пользователь 1184164 просмотрел 5 статей
# Пользователь 30405 просмотрел 7 статей
# Пользователь 493799 просмотрел 5 статей
# Пользователь 721993 просмотрел 5 статей
# Пользователь 1132014 просмотрел 8 статей
# Пользователь 1196336 просмотрел 4 статей
# Пользователь 352922 просмотрел 7 статей
# Пользователь 1308556 просмотрел 30 статей
# Пользователь 84455 просмотрел 5 статей
# Пользователь 166113 просмотрел 6 статей
# Пользователь 1122920 просмотрел 6 статей
# Пользователь 1287719 просмотрел 5 статей
# Пользователь 1272855 просмотрел 3 статей
# Пользователь 1313418 просмотрел 10 статей
# Пользователь 58987 просмотрел 4 статей
# Пользователь 182764 просмотрел 5 статей
# Пользователь 1007326 просмотрел 21 статей
# Пользователь 663966 просмотрел 18 статей
# Пользователь 1226658 просмотрел 5 статей
# Пользователь 1247289 просмотрел 4 статей
# Пользователь 1260764 просмотрел 5 статей
# Пользователь 132016 просмотрел 6 статей
# Пользователь 1278692 просмотрел 7 статей
# Пользователь 256653 просмотрел 4 статей
# Пользователь 1314752 просмотрел 4 статей
# Пользователь 1193526 просмотрел 11 статей
# Пользователь 1141659 просмотрел 4 статей
# Пользователь 1293732 просмотрел 5 статей
# Пользователь 1082648 просмотрел 6 статей
# Пользователь 1313582 просмотрел 8 статей
# Пользователь 16882 просмотрел 5 статей
# Пользователь 1174269 просмотрел 5 статей
# Пользователь 829067 просмотрел 6 статей
# Пользователь 1147341 просмотрел 4 статей
# Пользователь 1046816 просмотрел 3 статей
# Пользователь 1310514 просмотрел 6 статей
# Пользователь 682598 просмотрел 5 статей
# Пользователь 739876 просмотрел 10 статей
# Пользователь 1178261 просмотрел 4 статей
# Пользователь 1313898 просмотрел 3 статей
# Пользователь 1220189 просмотрел 9 статей
# Пользователь 1314883 просмотрел 8 статей
# Пользователь 13082 просмотрел 3 статей
# Пользователь 849509 просмотрел 4 статей
# Пользователь 1303099 просмотрел 6 статей
# Пользователь 1316124 просмотрел 4 статей
# Пользователь 1280792 просмотрел 4 статей
# Пользователь 43174 просмотрел 4 статей
# Пользователь 190022 просмотрел 4 статей
# Пользователь 76698 просмотрел 7 статей
# Пользователь 691202 просмотрел 18 статей
# Пользователь 70293 просмотрел 4 статей
# Пользователь 1275651 просмотрел 6 статей
# Пользователь 1316656 просмотрел 7 статей
# Пользователь 761972 просмотрел 4 статей
# Пользователь 1242715 просмотрел 4 статей
# Пользователь 1168457 просмотрел 4 статей
# Пользователь 1184918 просмотрел 4 статей
# Пользователь 1195924 просмотрел 5 статей
# Пользователь 519310 просмотрел 6 статей
# Пользователь 1316349 просмотрел 4 статей
# Пользователь 1158786 просмотрел 5 статей
# Пользователь 1263269 просмотрел 4 статей
# Пользователь 1316063 просмотрел 6 статей
# Пользователь 635334 просмотрел 6 статей
# Пользователь 1288816 просмотрел 8 статей
# Пользователь 78287 просмотрел 4 статей
# Пользователь 910063 просмотрел 9 статей
# Пользователь 1306533 просмотрел 3 статей
# Пользователь 1317654 просмотрел 4 статей
# Пользователь 1317486 просмотрел 4 статей
# Пользователь 907390 просмотрел 4 статей
# Пользователь 1263313 просмотрел 7 статей
# Пользователь 591925 просмотрел 5 статей
# Пользователь 1317711 просмотрел 4 статей
# Пользователь 1110508 просмотрел 7 статей
# Пользователь 397535 просмотрел 5 статей
# Пользователь 1268426 просмотрел 8 статей
# Пользователь 1316389 просмотрел 5 статей
# Пользователь 1313462 просмотрел 4 статей
# Пользователь 658204 просмотрел 4 статей
# Пользователь 1105028 просмотрел 4 статей
# Пользователь 327854 просмотрел 4 статей
# Пользователь 932429 просмотрел 4 статей
# Пользователь 910273 просмотрел 4 статей
# Пользователь 1314734 просмотрел 3 статей
# Пользователь 1308888 просмотрел 4 статей
# Пользователь 1298556 просмотрел 5 статей
# Пользователь 1305840 просмотрел 5 статей
# Пользователь 1282488 просмотрел 10 статей
# Пользователь 1292824 просмотрел 5 статей
# Пользователь 926224 просмотрел 5 статей
# Пользователь 1319715 просмотрел 4 статей
# Пользователь 1215786 просмотрел 6 статей
# Пользователь 1290494 просмотрел 4 статей
# Пользователь 1047061 просмотрел 5 статей
# Пользователь 365297 просмотрел 4 статей
# Пользователь 1318976 просмотрел 4 статей
# Пользователь 605178 просмотрел 4 статей
# Пользователь 1266506 просмотрел 7 статей
# Пользователь 1121926 просмотрел 4 статей
# Пользователь 1316438 просмотрел 6 статей
# Пользователь 1067217 просмотрел 5 статей
# Пользователь 1246602 просмотрел 5 статей
# Пользователь 272451 просмотрел 5 статей
# Пользователь 659368 просмотрел 4 статей
# Пользователь 280113 просмотрел 5 статей
# Пользователь 1320665 просмотрел 12 статей
# Пользователь 1319747 просмотрел 12 статей
# Пользователь 1309928 просмотрел 4 статей
# Пользователь 932206 просмотрел 5 статей
# Пользователь 1111256 просмотрел 5 статей
# Пользователь 1259307 просмотрел 4 статей
# Пользователь 1217306 просмотрел 4 статей
# Пользователь 1272124 просмотрел 5 статей
# Пользователь 1137187 просмотрел 6 статей
# Пользователь 1315147 просмотрел 9 статей
# Пользователь 1311492 просмотрел 5 статей
# Пользователь 596410 просмотрел 5 статей
# Пользователь 484078 просмотрел 5 статей
# Пользователь 29356 просмотрел 4 статей
# Пользователь 1308027 просмотрел 5 статей
# Пользователь 1198809 просмотрел 5 статей
# Пользователь 1322511 просмотрел 4 статей
# Пользователь 315199 просмотрел 6 статей
# Пользователь 1321120 просмотрел 7 статей
# Пользователь 1224841 просмотрел 8 статей
# Пользователь 1321309 просмотрел 4 статей
# Пользователь 1321859 просмотрел 5 статей
# Пользователь 771037 просмотрел 4 статей
# Пользователь 1166377 просмотрел 6 статей
# Пользователь 1320145 просмотрел 6 статей
# Пользователь 1322931 просмотрел 7 статей
# Пользователь 1321724 просмотрел 5 статей
# Пользователь 1323012 просмотрел 6 статей
# Пользователь 551541 просмотрел 9 статей
# Пользователь 920497 просмотрел 6 статей
# Пользователь 1093583 просмотрел 7 статей
# Пользователь 157709 просмотрел 6 статей
# Пользователь 1287730 просмотрел 4 статей
# Пользователь 892594 просмотрел 8 статей
# Пользователь 822471 просмотрел 5 статей
# Пользователь 142849 просмотрел 6 статей
# Пользователь 962040 просмотрел 5 статей
# Пользователь 1039518 просмотрел 4 статей
# Пользователь 1049448 просмотрел 8 статей
# Пользователь 1299949 просмотрел 3 статей
# Пользователь 1322630 просмотрел 4 статей
# Пользователь 27082 просмотрел 5 статей
# Пользователь 1085588 просмотрел 9 статей
# Пользователь 1323612 просмотрел 6 статей
# Пользователь 346437 просмотрел 15 статей
# Пользователь 1319149 просмотрел 4 статей
# Пользователь 1323976 просмотрел 4 статей
# Пользователь 539588 просмотрел 6 статей
# Пользователь 1321090 просмотрел 4 статей
# Пользователь 1302929 просмотрел 6 статей
# Пользователь 24730 просмотрел 5 статей
# Пользователь 976229 просмотрел 8 статей
# Пользователь 1222266 просмотрел 7 статей
# Пользователь 856571 просмотрел 5 статей
# Пользователь 94306 просмотрел 4 статей
# Пользователь 455492 просмотрел 16 статей
# Пользователь 929847 просмотрел 4 статей
# Пользователь 1324000 просмотрел 4 статей
# Пользователь 1300176 просмотрел 5 статей
# Пользователь 491657 просмотрел 5 статей
# Пользователь 1062663 просмотрел 4 статей
# Пользователь 1246533 просмотрел 2 статей
# Пользователь 1171256 просмотрел 5 статей
# Пользователь 1045763 просмотрел 4 статей
# Пользователь 633515 просмотрел 6 статей
# Пользователь 546445 просмотрел 7 статей
# Пользователь 67537 просмотрел 6 статей
# Пользователь 1160834 просмотрел 5 статей
# Пользователь 153345 просмотрел 6 статей
# Пользователь 1326036 просмотрел 4 статей
# Пользователь 1326086 просмотрел 1 статей
# Пользователь 820989 просмотрел 8 статей
# Пользователь 972132 просмотрел 7 статей
# Пользователь 1306165 просмотрел 3 статей
# Пользователь 1325988 просмотрел 6 статей
# Пользователь 577212 просмотрел 5 статей
# Пользователь 61214 просмотрел 5 статей
# Пользователь 174267 просмотрел 3 статей
# Пользователь 1326828 просмотрел 9 статей
# Пользователь 133211 просмотрел 4 статей
# Пользователь 1221276 просмотрел 5 статей
# Пользователь 1014406 просмотрел 4 статей
# Пользователь 1326075 просмотрел 13 статей
# Пользователь 671747 просмотрел 3 статей
# Пользователь 1165484 просмотрел 5 статей
# Пользователь 1323400 просмотрел 5 статей
# Пользователь 1311845 просмотрел 4 статей
# Пользователь 1021663 просмотрел 4 статей
# Пользователь 149713 просмотрел 14 статей
# Пользователь 1250733 просмотрел 8 статей
# Пользователь 1327367 просмотрел 18 статей
# Пользователь 1264739 просмотрел 3 статей
# Пользователь 1290786 просмотрел 5 статей
# Пользователь 1224988 просмотрел 4 статей
# Пользователь 1211239 просмотрел 9 статей
# Пользователь 1329136 просмотрел 8 статей
# Пользователь 230057 просмотрел 5 статей
# Пользователь 1329302 просмотрел 4 статей
# Пользователь 1329114 просмотрел 7 статей
# Пользователь 1329515 просмотрел 4 статей
# Пользователь 935900 просмотрел 4 статей
# Пользователь 1151718 просмотрел 8 статей
# Пользователь 128230 просмотрел 5 статей
# Пользователь 1306464 просмотрел 4 статей
# Пользователь 434635 просмотрел 4 статей
# Пользователь 90486 просмотрел 4 статей
# Пользователь 1212636 просмотрел 4 статей
# Пользователь 597450 просмотрел 6 статей
# Пользователь 1323852 просмотрел 5 статей
# Пользователь 199636 просмотрел 6 статей
# Пользователь 106846 просмотрел 4 статей
# Пользователь 1324063 просмотрел 4 статей
# Пользователь 1325948 просмотрел 6 статей
# Пользователь 1255605 просмотрел 4 статей
# Пользователь 1330718 просмотрел 9 статей
# Пользователь 1327498 просмотрел 7 статей
# Пользователь 1136364 просмотрел 4 статей
# Пользователь 70150 просмотрел 4 статей
# Пользователь 1185199 просмотрел 5 статей
# Пользователь 1124615 просмотрел 5 статей
# Пользователь 1285016 просмотрел 4 статей
# Пользователь 1268633 просмотрел 5 статей
# Пользователь 1317859 просмотрел 8 статей
# Пользователь 786594 просмотрел 36 статей
# Пользователь 560585 просмотрел 4 статей
# Пользователь 1314207 просмотрел 6 статей
# Пользователь 1106301 просмотрел 5 статей
# Пользователь 1331385 просмотрел 10 статей
# Пользователь 1331566 просмотрел 24 статей
# Пользователь 1262223 просмотрел 7 статей
# Пользователь 1118324 просмотрел 5 статей
# Пользователь 263176 просмотрел 11 статей
# Пользователь 66515 просмотрел 3 статей
# Пользователь 1332072 просмотрел 5 статей
# Пользователь 910678 просмотрел 4 статей
# Пользователь 94599 просмотрел 4 статей
# Пользователь 1039998 просмотрел 4 статей
# Пользователь 1331648 просмотрел 5 статей
# Пользователь 1325388 просмотрел 4 статей
# Пользователь 1323938 просмотрел 4 статей
# Пользователь 408674 просмотрел 12 статей
# Пользователь 1241670 просмотрел 6 статей
# Пользователь 1332477 просмотрел 4 статей
# Пользователь 1308007 просмотрел 4 статей
# Пользователь 1332143 просмотрел 8 статей
# Пользователь 1332824 просмотрел 3 статей
# Пользователь 1304787 просмотрел 8 статей
# Пользователь 611878 просмотрел 6 статей
# Пользователь 1293731 просмотрел 4 статей
# Пользователь 434223 просмотрел 4 статей
# Пользователь 395490 просмотрел 6 статей
# Пользователь 867644 просмотрел 4 статей
# Пользователь 1083913 просмотрел 5 статей
# Пользователь 1324932 просмотрел 3 статей
# Пользователь 1313095 просмотрел 25 статей
# Пользователь 896804 просмотрел 5 статей
# Пользователь 1329904 просмотрел 5 статей
# Пользователь 806704 просмотрел 4 статей
# Пользователь 1333842 просмотрел 8 статей
# Пользователь 1212390 просмотрел 4 статей
# Пользователь 1291974 просмотрел 7 статей
# Пользователь 1333793 просмотрел 11 статей
# Пользователь 883940 просмотрел 4 статей
# Пользователь 1334568 просмотрел 11 статей
# Пользователь 1334438 просмотрел 5 статей
# Пользователь 575216 просмотрел 4 статей
# Пользователь 375803 просмотрел 4 статей
# Пользователь 260456 просмотрел 5 статей
# Пользователь 1114920 просмотрел 4 статей
# Пользователь 1302103 просмотрел 5 статей
# Пользователь 1330047 просмотрел 4 статей
# Пользователь 1208227 просмотрел 4 статей
# Пользователь 1161943 просмотрел 3 статей
# Пользователь 994962 просмотрел 6 статей
# Пользователь 301052 просмотрел 4 статей
# Пользователь 1336193 просмотрел 4 статей
# Пользователь 1185006 просмотрел 5 статей
# Пользователь 1288978 просмотрел 3 статей
# Пользователь 853578 просмотрел 5 статей
# Пользователь 208304 просмотрел 4 статей
# Пользователь 363959 просмотрел 4 статей
# Пользователь 1330510 просмотрел 4 статей
# Пользователь 819515 просмотрел 4 статей
# Пользователь 1337029 просмотрел 18 статей
# Пользователь 32090 просмотрел 9 статей
# Пользователь 1307364 просмотрел 17 статей
# Пользователь 1290473 просмотрел 5 статей
# Пользователь 994902 просмотрел 10 статей
# Пользователь 1232035 просмотрел 3 статей
# Пользователь 3670 просмотрел 6 статей
# Пользователь 1331915 просмотрел 8 статей
# Пользователь 1312774 просмотрел 16 статей
# Пользователь 1313346 просмотрел 5 статей
# Пользователь 776274 просмотрел 10 статей
# Пользователь 1293685 просмотрел 4 статей
# Пользователь 477323 просмотрел 4 статей
# Пользователь 670363 просмотрел 5 статей
# Пользователь 1335829 просмотрел 37 статей
# Пользователь 1286531 просмотрел 4 статей
# Пользователь 1338117 просмотрел 11 статей
# Пользователь 1338359 просмотрел 5 статей
# Пользователь 605148 просмотрел 8 статей
# Пользователь 31515 просмотрел 5 статей
# Пользователь 1269671 просмотрел 4 статей
# Пользователь 1338684 просмотрел 8 статей
# Пользователь 1300432 просмотрел 6 статей
# Пользователь 1315102 просмотрел 6 статей
# Пользователь 1290168 просмотрел 7 статей
# Пользователь 1293466 просмотрел 7 статей
# Пользователь 358160 просмотрел 4 статей
# Пользователь 1282607 просмотрел 8 статей
# Пользователь 1267360 просмотрел 5 статей
# Пользователь 1207737 просмотрел 3 статей
# Пользователь 646608 просмотрел 3 статей
# Пользователь 324250 просмотрел 4 статей
# Пользователь 155466 просмотрел 4 статей
# Пользователь 1316271 просмотрел 5 статей
# Пользователь 731520 просмотрел 13 статей
# Пользователь 1339758 просмотрел 5 статей
# Пользователь 110978 просмотрел 5 статей
# Пользователь 772730 просмотрел 4 статей
# Пользователь 801560 просмотрел 5 статей
# Пользователь 1337927 просмотрел 4 статей
# Пользователь 1282828 просмотрел 4 статей
# Пользователь 1208468 просмотрел 5 статей
# Пользователь 1340337 просмотрел 4 статей
# Пользователь 1008795 просмотрел 4 статей
# Пользователь 1196839 просмотрел 4 статей
# Пользователь 1231896 просмотрел 4 статей
# Пользователь 1339208 просмотрел 4 статей
# Пользователь 1340295 просмотрел 2 статей
# Пользователь 1011890 просмотрел 5 статей
# Пользователь 1283480 просмотрел 4 статей
# Пользователь 1262733 просмотрел 4 статей
# Пользователь 455828 просмотрел 15 статей
# Пользователь 1341229 просмотрел 4 статей
# Пользователь 1090121 просмотрел 9 статей
# Пользователь 956815 просмотрел 5 статей
# Пользователь 1069384 просмотрел 4 статей
# Пользователь 1074464 просмотрел 7 статей
# Пользователь 1092158 просмотрел 5 статей
# Пользователь 463640 просмотрел 4 статей
# Пользователь 1336706 просмотрел 4 статей
# Пользователь 1286084 просмотрел 5 статей
# Пользователь 1321269 просмотрел 4 статей
# Пользователь 723299 просмотрел 4 статей
# Пользователь 1255375 просмотрел 4 статей
# Пользователь 1336461 просмотрел 7 статей
# Пользователь 244265 просмотрел 9 статей
# Пользователь 1290507 просмотрел 4 статей
# Пользователь 1261271 просмотрел 25 статей
# Пользователь 422142 просмотрел 4 статей
# Пользователь 1075787 просмотрел 6 статей
# Пользователь 1343173 просмотрел 4 статей
# Пользователь 1307764 просмотрел 5 статей
# Пользователь 1321384 просмотрел 4 статей
# Пользователь 131166 просмотрел 5 статей
# Пользователь 1336939 просмотрел 12 статей
# Пользователь 1331080 просмотрел 5 статей
# Пользователь 1296136 просмотрел 4 статей
# Пользователь 909927 просмотрел 17 статей
# Пользователь 727380 просмотрел 8 статей
# Пользователь 1342464 просмотрел 6 статей
# Пользователь 1259579 просмотрел 8 статей
# Пользователь 651651 просмотрел 4 статей
# Пользователь 131724 просмотрел 5 статей
# Пользователь 1343317 просмотрел 4 статей
# Пользователь 748893 просмотрел 4 статей
# Пользователь 1341597 просмотрел 4 статей
# Пользователь 336080 просмотрел 4 статей
# Пользователь 1212963 просмотрел 5 статей
# Пользователь 1340077 просмотрел 7 статей
# Пользователь 1342310 просмотрел 4 статей
# Пользователь 621364 просмотрел 3 статей
# Пользователь 470160 просмотрел 4 статей
# Пользователь 1292552 просмотрел 5 статей
# Пользователь 1345078 просмотрел 4 статей
# Пользователь 1292414 просмотрел 7 статей
# Пользователь 542091 просмотрел 5 статей
# Пользователь 1344551 просмотрел 3 статей
# Пользователь 1336081 просмотрел 7 статей
# Пользователь 1132817 просмотрел 14 статей
# Пользователь 1332247 просмотрел 10 статей
# Пользователь 1338461 просмотрел 4 статей
# Пользователь 274019 просмотрел 4 статей
# Пользователь 982971 просмотрел 7 статей
# Пользователь 1344812 просмотрел 5 статей
# Пользователь 1048138 просмотрел 8 статей
# Пользователь 46787 просмотрел 5 статей
# Пользователь 1332691 просмотрел 4 статей
# Пользователь 1346320 просмотрел 4 статей
# Пользователь 1331518 просмотрел 11 статей
# Пользователь 1258004 просмотрел 5 статей
# Пользователь 1344521 просмотрел 41 статей
# Пользователь 1347038 просмотрел 4 статей
# Пользователь 371653 просмотрел 4 статей
# Пользователь 19290 просмотрел 3 статей
# Пользователь 577062 просмотрел 12 статей
# Пользователь 1159553 просмотрел 5 статей
# Пользователь 487844 просмотрел 6 статей
# Пользователь 25009 просмотрел 5 статей
# Пользователь 1347799 просмотрел 4 статей
# Пользователь 1347900 просмотрел 3 статей
# Пользователь 1340177 просмотрел 4 статей
# Пользователь 1346863 просмотрел 7 статей
# Пользователь 1007630 просмотрел 5 статей
# Пользователь 192793 просмотрел 6 статей
# Пользователь 1207300 просмотрел 8 статей
# Пользователь 1064531 просмотрел 3 статей
# Пользователь 1346836 просмотрел 6 статей
# Пользователь 589732 просмотрел 6 статей
# Пользователь 1332937 просмотрел 4 статей
# Пользователь 1307609 просмотрел 6 статей
# Пользователь 273343 просмотрел 4 статей
# Пользователь 1323441 просмотрел 3 статей
# Пользователь 788357 просмотрел 5 статей
# Пользователь 1336715 просмотрел 6 статей
# Пользователь 1263528 просмотрел 4 статей
# Пользователь 151714 просмотрел 6 статей
# Пользователь 1337743 просмотрел 3 статей
# Пользователь 1283968 просмотрел 5 статей
# Пользователь 1211912 просмотрел 4 статей
# Пользователь 25199 просмотрел 6 статей
# Пользователь 1347386 просмотрел 4 статей
# Пользователь 1351101 просмотрел 6 статей
# Пользователь 1319580 просмотрел 4 статей
# Пользователь 112284 просмотрел 3 статей
# Пользователь 1105434 просмотрел 4 статей
# Пользователь 1145498 просмотрел 5 статей
# Пользователь 1351588 просмотрел 6 статей
# Пользователь 1347451 просмотрел 7 статей
# Пользователь 1324155 просмотрел 7 статей
# Пользователь 1336349 просмотрел 4 статей
# Пользователь 1319667 просмотрел 8 статей
# Пользователь 646271 просмотрел 4 статей
# Пользователь 1339892 просмотрел 8 статей
# Пользователь 954650 просмотрел 5 статей
# Пользователь 388893 просмотрел 6 статей
# Пользователь 445858 просмотрел 6 статей
# Пользователь 1127189 просмотрел 4 статей
# Пользователь 1003047 просмотрел 13 статей
# Пользователь 1324207 просмотрел 4 статей
# Пользователь 946976 просмотрел 3 статей
# Пользователь 332729 просмотрел 5 статей
# Пользователь 1050023 просмотрел 7 статей
# Пользователь 431633 просмотрел 4 статей
# Пользователь 1351422 просмотрел 4 статей
# Пользователь 1242856 просмотрел 4 статей
# Пользователь 1344039 просмотрел 8 статей
# Пользователь 609824 просмотрел 4 статей
# Пользователь 1340575 просмотрел 15 статей
# Пользователь 139039 просмотрел 3 статей
# Пользователь 693767 просмотрел 5 статей
# Пользователь 31189 просмотрел 13 статей
# Пользователь 1322633 просмотрел 5 статей
# Пользователь 1352819 просмотрел 4 статей
# Пользователь 1351205 просмотрел 8 статей
# Пользователь 1346331 просмотрел 7 статей
# Пользователь 179329 просмотрел 3 статей
# Пользователь 1252794 просмотрел 4 статей
# Пользователь 1349688 просмотрел 4 статей
# Пользователь 1333746 просмотрел 6 статей
# Пользователь 785167 просмотрел 4 статей
# Пользователь 333322 просмотрел 5 статей
# Пользователь 1346065 просмотрел 5 статей
# Пользователь 1319545 просмотрел 4 статей
# Пользователь 1353608 просмотрел 4 статей
# Пользователь 1351502 просмотрел 7 статей
# Пользователь 1262037 просмотрел 9 статей
# Пользователь 1348066 просмотрел 4 статей
# Пользователь 1043009 просмотрел 6 статей
# Пользователь 1254765 просмотрел 4 статей
# Пользователь 1344700 просмотрел 6 статей
# Пользователь 163839 просмотрел 6 статей
# Пользователь 1285670 просмотрел 6 статей
# Пользователь 1339935 просмотрел 6 статей
# Пользователь 1244817 просмотрел 4 статей
# Пользователь 1355428 просмотрел 4 статей
# Пользователь 1192564 просмотрел 5 статей
# Пользователь 1355987 просмотрел 6 статей
# Пользователь 175828 просмотрел 6 статей
# Пользователь 1348290 просмотрел 8 статей
# Пользователь 1073169 просмотрел 4 статей
# Пользователь 1318978 просмотрел 4 статей
# Пользователь 1353175 просмотрел 4 статей
# Пользователь 1101688 просмотрел 8 статей
# Пользователь 1356071 просмотрел 4 статей
# Пользователь 1348354 просмотрел 14 статей
# Пользователь 1356120 просмотрел 11 статей
# Пользователь 1276875 просмотрел 4 статей
# Пользователь 1029065 просмотрел 3 статей
# Пользователь 1050118 просмотрел 4 статей
# Пользователь 748523 просмотрел 8 статей
# Пользователь 1357346 просмотрел 3 статей
# Пользователь 573378 просмотрел 12 статей
# Пользователь 1197895 просмотрел 11 статей
# Пользователь 1140509 просмотрел 11 статей
# Пользователь 55961 просмотрел 4 статей
# Пользователь 1350635 просмотрел 6 статей
# Пользователь 822577 просмотрел 4 статей
# Пользователь 1213473 просмотрел 12 статей
# Пользователь 1281311 просмотрел 4 статей
# Пользователь 1356450 просмотрел 5 статей
# Пользователь 449195 просмотрел 3 статей
# Пользователь 1343620 просмотрел 4 статей
# Пользователь 1360959 просмотрел 6 статей
# Пользователь 719362 просмотрел 6 статей
# Пользователь 1331979 просмотрел 7 статей
# Пользователь 981347 просмотрел 5 статей
# Пользователь 1040661 просмотрел 4 статей
# Пользователь 922969 просмотрел 5 статей
# Пользователь 507293 просмотрел 5 статей
# Пользователь 1361123 просмотрел 8 статей
# Пользователь 1352755 просмотрел 6 статей
# Пользователь 1070228 просмотрел 6 статей
# Пользователь 540721 просмотрел 4 статей
# Пользователь 261014 просмотрел 3 статей
# Пользователь 551690 просмотрел 4 статей
# Пользователь 963267 просмотрел 5 статей
# Пользователь 680404 просмотрел 5 статей
# Пользователь 1361312 просмотрел 5 статей
# Пользователь 1364894 просмотрел 4 статей
# Пользователь 1207552 просмотрел 4 статей
# Пользователь 1091259 просмотрел 4 статей
# Пользователь 1358397 просмотрел 3 статей
# Пользователь 1130808 просмотрел 1 статей
# Пользователь 1364744 просмотрел 5 статей
# Пользователь 1278242 просмотрел 7 статей
# Пользователь 725530 просмотрел 4 статей
# Пользователь 1343979 просмотрел 4 статей
# Пользователь 1276006 просмотрел 4 статей
# Пользователь 809112 просмотрел 4 статей
# Пользователь 1173669 просмотрел 4 статей
# Пользователь 1102728 просмотрел 5 статей
# Пользователь 1333222 просмотрел 8 статей
# Пользователь 1356416 просмотрел 5 статей
# Пользователь 1314495 просмотрел 6 статей
# Пользователь 1366196 просмотрел 8 статей
# Пользователь 399105 просмотрел 4 статей
# Пользователь 1367224 просмотрел 4 статей
# Пользователь 1368935 просмотрел 8 статей
# Пользователь 1360750 просмотрел 11 статей
# Пользователь 1137595 просмотрел 4 статей
# Пользователь 1162801 просмотрел 11 статей
# Пользователь 1100715 просмотрел 2 статей
# Пользователь 1080491 просмотрел 4 статей
# Пользователь 1361454 просмотрел 4 статей
# Пользователь 1344172 просмотрел 5 статей
# Пользователь 987763 просмотрел 4 статей
# Пользователь 1369669 просмотрел 3 статей
# Пользователь 1109020 просмотрел 5 статей
# Пользователь 1005244 просмотрел 4 статей
# Пользователь 1356381 просмотрел 8 статей
# Пользователь 1364682 просмотрел 4 статей
# Пользователь 1370141 просмотрел 3 статей
# Пользователь 284321 просмотрел 7 статей
# Пользователь 1182704 просмотрел 4 статей
# Пользователь 867694 просмотрел 5 статей
# Пользователь 405825 просмотрел 4 статей
# Пользователь 1370384 просмотрел 3 статей
# Пользователь 1356246 просмотрел 1 статей
# Пользователь 663237 просмотрел 4 статей
# Пользователь 1294793 просмотрел 5 статей
# Пользователь 824839 просмотрел 4 статей
# Пользователь 857434 просмотрел 6 статей
# Пользователь 1112163 просмотрел 6 статей
# Пользователь 475806 просмотрел 5 статей
# Пользователь 1371083 просмотрел 7 статей
# Пользователь 1371148 просмотрел 6 статей
# Пользователь 752235 просмотрел 4 статей
# Пользователь 1001445 просмотрел 4 статей
# Пользователь 1366578 просмотрел 4 статей
# Пользователь 1342430 просмотрел 4 статей
# Пользователь 1364757 просмотрел 5 статей
# Пользователь 1269924 просмотрел 3 статей
# Пользователь 1372738 просмотрел 5 статей
# Пользователь 60043 просмотрел 4 статей
# Пользователь 1373533 просмотрел 5 статей
# Пользователь 1160697 просмотрел 6 статей
# Пользователь 757506 просмотрел 5 статей
# Пользователь 1178018 просмотрел 5 статей
# Пользователь 672636 просмотрел 3 статей
# Пользователь 1335198 просмотрел 9 статей
# Пользователь 1372064 просмотрел 1 статей
# Пользователь 1063030 просмотрел 4 статей
# Пользователь 1375129 просмотрел 7 статей
# Пользователь 1243418 просмотрел 5 статей
# Пользователь 1358658 просмотрел 3 статей
# Пользователь 1352933 просмотрел 4 статей
# Пользователь 1373055 просмотрел 4 статей
# Пользователь 1375197 просмотрел 5 статей
# Пользователь 1375654 просмотрел 5 статей
# Пользователь 1355803 просмотрел 7 статей
# Пользователь 1345418 просмотрел 22 статей
# Пользователь 1156701 просмотрел 4 статей
# Пользователь 1372664 просмотрел 5 статей
# Пользователь 1250776 просмотрел 4 статей
# Пользователь 1375813 просмотрел 4 статей
# Пользователь 1357565 просмотрел 4 статей
# Пользователь 315267 просмотрел 4 статей
# Пользователь 366625 просмотрел 5 статей
# Пользователь 1271831 просмотрел 17 статей
# Пользователь 1359828 просмотрел 6 статей
# Пользователь 893892 просмотрел 3 статей
# Пользователь 1376934 просмотрел 8 статей
# Пользователь 1220661 просмотрел 7 статей
# Пользователь 1280067 просмотрел 6 статей
# Пользователь 1377407 просмотрел 4 статей
# Пользователь 1377903 просмотрел 5 статей
# Пользователь 1372678 просмотрел 9 статей
# Пользователь 1352001 просмотрел 4 статей
# Пользователь 1013543 просмотрел 4 статей
# Пользователь 592024 просмотрел 9 статей
# Пользователь 1166266 просмотрел 4 статей
# Пользователь 967272 просмотрел 4 статей
# Пользователь 1360312 просмотрел 4 статей
# Пользователь 1205292 просмотрел 4 статей
# Пользователь 417273 просмотрел 4 статей
# Пользователь 78331 просмотрел 5 статей
# Пользователь 1379021 просмотрел 4 статей
# Пользователь 1378929 просмотрел 4 статей
# Пользователь 1375173 просмотрел 5 статей
# Пользователь 1199285 просмотрел 4 статей
# Пользователь 1193502 просмотрел 4 статей
# Пользователь 1372728 просмотрел 5 статей
# Пользователь 1323887 просмотрел 6 статей
# Пользователь 4052 просмотрел 4 статей
# Пользователь 1378648 просмотрел 5 статей
# Пользователь 1001863 просмотрел 6 статей
# Пользователь 377299 просмотрел 6 статей
# Пользователь 1377504 просмотрел 6 статей
# Пользователь 1138835 просмотрел 5 статей
# Пользователь 657851 просмотрел 4 статей
# Пользователь 1379022 просмотрел 4 статей
# Пользователь 1359426 просмотрел 4 статей
# Пользователь 624181 просмотрел 4 статей
# Пользователь 1381208 просмотрел 5 статей
# Пользователь 1352839 просмотрел 4 статей
# Пользователь 1219735 просмотрел 1 статей
# Пользователь 1365473 просмотрел 4 статей
# Пользователь 1383145 просмотрел 7 статей
# Пользователь 1381229 просмотрел 4 статей
# Пользователь 1053139 просмотрел 6 статей
# Пользователь 1383088 просмотрел 4 статей
# Пользователь 1376813 просмотрел 4 статей
# Пользователь 1073613 просмотрел 2 статей
# Пользователь 1383038 просмотрел 4 статей
# Пользователь 1375119 просмотрел 4 статей
# Пользователь 1230438 просмотрел 2 статей
# Пользователь 762166 просмотрел 4 статей
# Пользователь 1243306 просмотрел 5 статей
# Пользователь 1381318 просмотрел 4 статей
# Пользователь 1340426 просмотрел 4 статей
# Пользователь 1385192 просмотрел 4 статей
# Пользователь 454349 просмотрел 4 статей
# Пользователь 862141 просмотрел 4 статей
# Пользователь 559374 просмотрел 8 статей
# Пользователь 1385734 просмотрел 5 статей
# Пользователь 1385742 просмотрел 3 статей
# Пользователь 1383845 просмотрел 4 статей
# Пользователь 44865 просмотрел 3 статей
# Пользователь 341500 просмотрел 4 статей
# Пользователь 1386848 просмотрел 3 статей
# Пользователь 1358340 просмотрел 4 статей
# Пользователь 1358637 просмотрел 4 статей
# Пользователь 1372095 просмотрел 5 статей
# Пользователь 1378566 просмотрел 5 статей
# Пользователь 1353007 просмотрел 7 статей
# Пользователь 1357963 просмотрел 4 статей
# Пользователь 1387924 просмотрел 4 статей
# Пользователь 1366193 просмотрел 4 статей
# Пользователь 476191 просмотрел 4 статей
# Пользователь 647155 просмотрел 4 статей
# Пользователь 1388209 просмотрел 13 статей
# Пользователь 1192866 просмотрел 4 статей
# Пользователь 1388588 просмотрел 4 статей
# Пользователь 1388853 просмотрел 4 статей
# Пользователь 1387879 просмотрел 5 статей
# Пользователь 1385495 просмотрел 27 статей
# Пользователь 110270 просмотрел 4 статей
# Пользователь 34825 просмотрел 4 статей
# Пользователь 1390355 просмотрел 4 статей
# Пользователь 1388773 просмотрел 5 статей
# Пользователь 327460 просмотрел 3 статей
# Пользователь 1391093 просмотрел 4 статей
# Пользователь 1157820 просмотрел 14 статей
# Пользователь 1223726 просмотрел 4 статей
# Пользователь 1370985 просмотрел 6 статей
# Пользователь 1392244 просмотрел 6 статей
# Пользователь 1389977 просмотрел 11 статей
# Пользователь 1024567 просмотрел 6 статей
# Пользователь 784361 просмотрел 11 статей
# Пользователь 1392947 просмотрел 7 статей
# Пользователь 935372 просмотрел 8 статей
# Пользователь 1071668 просмотрел 4 статей
# Пользователь 177469 просмотрел 4 статей
# Пользователь 1394290 просмотрел 15 статей
# Пользователь 1358878 просмотрел 4 статей
# Пользователь 980976 просмотрел 4 статей
# Пользователь 1355448 просмотрел 5 статей
# Пользователь 1395100 просмотрел 8 статей
# Пользователь 597395 просмотрел 4 статей
# Пользователь 1371319 просмотрел 8 статей
# Пользователь 1379436 просмотрел 7 статей
# Пользователь 1396493 просмотрел 5 статей
# Пользователь 595690 просмотрел 4 статей
# Пользователь 1391992 просмотрел 5 статей
# Пользователь 1386336 просмотрел 7 статей
# Пользователь 1356228 просмотрел 5 статей
# Пользователь 1396802 просмотрел 4 статей
# Пользователь 964186 просмотрел 6 статей
# Пользователь 21545 просмотрел 5 статей
# Пользователь 1398138 просмотрел 11 статей
# Пользователь 1397611 просмотрел 5 статей
# Пользователь 657643 просмотрел 4 статей
# Пользователь 1393534 просмотрел 5 статей
# Пользователь 1315090 просмотрел 4 статей
# Пользователь 1016786 просмотрел 5 статей
# Пользователь 1382508 просмотрел 4 статей
# Пользователь 1306671 просмотрел 3 статей
# Пользователь 1217343 просмотрел 3 статей
# Пользователь 1263711 просмотрел 5 статей
# Пользователь 1370179 просмотрел 8 статей
# Пользователь 1400880 просмотрел 6 статей
# Пользователь 1390400 просмотрел 4 статей
# Пользователь 1182093 просмотрел 4 статей
# Пользователь 1072437 просмотрел 1 статей
# Пользователь 1358950 просмотрел 5 статей
# Пользователь 1376075 просмотрел 5 статей
# Пользователь 1397937 просмотрел 4 статей
# Пользователь 1402980 просмотрел 4 статей
# Пользователь 1378578 просмотрел 5 статей
# Пользователь 1401559 просмотрел 9 статей
# Пользователь 686620 просмотрел 4 статей
# Пользователь 624572 просмотрел 5 статей
# Пользователь 104791 просмотрел 4 статей
# Пользователь 1331562 просмотрел 10 статей
# Пользователь 1406134 просмотрел 4 статей
# Пользователь 1405992 просмотрел 6 статей
# Пользователь 1368992 просмотрел 6 статей
# Пользователь 1105324 просмотрел 5 статей
# Пользователь 1390381 просмотрел 4 статей
# Пользователь 1407051 просмотрел 4 статей
# Пользователь 28605 просмотрел 4 статей
# Пользователь 1394919 просмотрел 4 статей
# Пользователь 1406578 просмотрел 4 статей
# Пользователь 1408273 просмотрел 3 статей
# Пользователь 1408252 просмотрел 4 статей
# Пользователь 1397675 просмотрел 4 статей
# Пользователь 1399299 просмотрел 4 статей
# Пользователь 1382494 просмотрел 4 статей
# Пользователь 1031317 просмотрел 6 статей
# Пользователь 1358839 просмотрел 5 статей
# Пользователь 602919 просмотрел 5 статей
# Пользователь 1410542 просмотрел 4 статей
# Пользователь 1409903 просмотрел 4 статей
# Пользователь 1378005 просмотрел 4 статей
# Пользователь 46144 просмотрел 5 статей
# Пользователь 1319767 просмотрел 1 статей
# Пользователь 1409523 просмотрел 4 статей
# Пользователь 1403135 просмотрел 4 статей
# Пользователь 1404596 просмотрел 4 статей
# Пользователь 1181868 просмотрел 4 статей
# Пользователь 1397930 просмотрел 4 статей
# Пользователь 1409461 просмотрел 5 статей
# Пользователь 1393986 просмотрел 4 статей
# Пользователь 111928 просмотрел 5 статей
# Пользователь 406478 просмотрел 3 статей
# Пользователь 360283 просмотрел 7 статей
# Пользователь 889949 просмотрел 4 статей
# Пользователь 1412861 просмотрел 5 статей
# Пользователь 1088254 просмотрел 4 статей
# Пользователь 268744 просмотрел 5 статей
# Пользователь 1250390 просмотрел 3 статей
# Пользователь 22684 просмотрел 5 статей
# Пользователь 867133 просмотрел 14 статей
# Пользователь 923959 просмотрел 6 статей
# Пользователь 1399768 просмотрел 4 статей
# Пользователь 712229 просмотрел 9 статей
# Пользователь 830958 просмотрел 7 статей
# Пользователь 166849 просмотрел 4 статей
# Пользователь 1174472 просмотрел 2 статей
# Пользователь 1385781 просмотрел 3 статей
# Пользователь 1420308 просмотрел 11 статей
# Пользователь 1019274 просмотрел 5 статей
# Пользователь 1420298 просмотрел 5 статей
# Пользователь 170891 просмотрел 5 статей
# Пользователь 1319054 просмотрел 5 статей
# Пользователь 689031 просмотрел 3 статей
# Пользователь 1413970 просмотрел 4 статей
# Пользователь 901577 просмотрел 8 статей
# Пользователь 1421754 просмотрел 4 статей
# Пользователь 1165875 просмотрел 4 статей
# Пользователь 1146985 просмотрел 4 статей
# Пользователь 1423831 просмотрел 4 статей
# Пользователь 1361109 просмотрел 2 статей
# Пользователь 1394092 просмотрел 4 статей
# Пользователь 1423756 просмотрел 6 статей
# Пользователь 988900 просмотрел 3 статей
# Пользователь 1418061 просмотрел 4 статей
# Пользователь 524438 просмотрел 4 статей
# Пользователь 1426588 просмотрел 4 статей
# Пользователь 1426507 просмотрел 4 статей
# Пользователь 383394 просмотрел 7 статей
# Пользователь 1336071 просмотрел 6 статей
# Пользователь 856683 просмотрел 3 статей
# Пользователь 527032 просмотрел 4 статей
# Пользователь 1410213 просмотрел 3 статей
# Пользователь 1360834 просмотрел 4 статей
# Пользователь 1428209 просмотрел 4 статей
# Пользователь 734218 просмотрел 7 статей
# Пользователь 530717 просмотрел 6 статей
# Пользователь 1145846 просмотрел 3 статей
# Пользователь 1429256 просмотрел 4 статей
# Пользователь 1420098 просмотрел 4 статей
# Пользователь 860943 просмотрел 6 статей
# Пользователь 1384142 просмотрел 5 статей
# Пользователь 1429842 просмотрел 4 статей
# Пользователь 1410098 просмотрел 7 статей
# Пользователь 1333133 просмотрел 3 статей
# Пользователь 411804 просмотрел 5 статей
# Пользователь 1231126 просмотрел 4 статей
# Сохранено 23640 рекомендаций для 1182 пользователей в файл user_recommendations_all.csv
