# %%
import logging
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.sparse import coo_matrix
from implicit.als import AlternatingLeastSquares
from implicit.nearest_neighbours import bm25_weight
from catboost import CatBoostRanker, Pool
from sklearn.model_selection import train_test_split

# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
# %config InlineBackend.figure_format = 'retina'
pd.set_option('display.max_columns', 50)  # Показывать до 50 колонок
pd.set_option('display.max_colwidth', 100)  # Показывать до 50 колонок

# %%
data = pd.read_excel("../cuprum_3.xlsx", sheet_name="Лист4") #cuprum/Лист4/Лист2/Лист1
data.rename(columns={"пол":"gender", "возраст":"age"}, inplace=True)
data = data[data['action_type'] == 'CLICKED']
data.drop(columns=["esb_ehr_id","patientnet_ehr_id", "medialog_ehr_id","action_type"], inplace=True)
data
# Out:
#             id                article_id   ehr_id created_at  gender  age
# 0      3744933  61c03691a7568f6cda4a0c95   961420 2023-07-01       2   35  \
# 1      3745298  5f22ce85e24e57105a57d2a5   100445 2023-07-01       1   37
# 2      3745310  5fdba88d08d6334b9536bd71   491804 2023-07-01       1   47
# 3      3745453  63ea42aaa6594aa87e07c4f2    65721 2023-07-01       1   53
# 4      3745512  608a88b3b587d22877730773  1281788 2023-07-01       2   74
# ...        ...                       ...      ...        ...     ...  ...
# 30835  9608721  63a9765bff95853c500cce62    97731 2024-07-30       1   49
# 30836  9608800  606dd15f70bc473f234d0092  1326732 2024-07-30       2   21
# 30837  9609015  615c6f0cf2896444877b8b64  1430340 2024-07-30       1   44
# 30838  9609066  654612ff65e72be96c09461b     5716 2024-07-30       1   46
# 30839  9609263  6411bda1c0547a0aba053b32  1425225 2024-07-30       1   41
#
#         birthday
# 0     1990-05-29  \
# 1     1987-09-26
# 2     1978-01-07
# 3     1972-02-03
# 4     1951-04-21
# ...          ...
# 30835 1976-05-09
# 30836 2004-02-12
# 30837 1981-01-29
# 30838 1978-12-11
# 30839 1983-08-03
#
#                                                                   title
# 0                                                 Чем опасна трипофобия  \
# 1      Мирамистин и хлоргексидин можно использовать вместо санитайзера?
# 2                Открываем окна: кому и как нужно проветривать квартиру
# 3                    Правда ли, что лампы для сушки ногтей вызывают рак
# 4                     Можно ли забеременеть от двух мужчин одновременно
# ...                                                                 ...
# 30835                    Почему возникают ошибки в результатах анализов
# 30836       Полиамория и сологамия: какими бывают современные отношения
# 30837                                  Как бороться с пигментацией кожи
# 30838                              Как избавиться от второго подбородка
# 30839                           Почему на ногтях появляются белые пятна
#
#                                                                                                        url
# 0                                             https://cuprum.media/science-answers/trypophobia?from=avaapp  \
# 1      https://cuprum.media/proverka-sluha/miramistin-i-hlorgeksidin-mozhno-ispolzovat-vmesto-sanitajze...
# 2                          https://cuprum.media/science-answers/how-to-ventilate-the-apartment?from=avaapp
# 3                                        https://cuprum.media/science-answers/nail-lamp-danger?from=avaapp
# 4                                     https://cuprum.media/stesnyayus-sprosit/superfecundation?from=avaapp
# ...                                                                                                    ...
# 30835                                   https://cuprum.media/science-answers/lab-test-mistakes?from=avaapp
# 30836                                     https://cuprum.media/lifestyle/romantic-relationship?from=avaapp
# 30837                                         https://cuprum.media/lifestyle/skin-pigmentation?from=avaapp
# 30838                             https://cuprum.media/science-answers/ubrat-vtoroy-podborodok?from=avaapp
# 30839                                                  https://cuprum.media/razbor/white-nails?from=avaapp
#
#          views published_date   formats
# 0        795.0     2021-12-20  longread  \
# 1       4005.0     2020-09-05  longread
# 2        554.0     2020-12-17  longread
# 3       8032.0     2023-02-13  longread
# 4      16787.0     2021-04-29  longread
# ...        ...            ...       ...
# 30835   5907.0     2023-01-04  longread
# 30836  10308.0     2021-04-07  longread
# 30837   4227.0     2021-10-05  longread
# 30838    741.0     2023-11-06  longread
# 30839  16685.0     2023-03-15  longread
#
#                                         tags        rubric_title
# 0                                          0   Ответили по науке
# 1      Пандемия,Профилактика,Патогены,Вирусы      Проверка слуха
# 2                                          0   Ответили по науке
# 3                   Вредное,Косметика,Булшит   Ответили по науке
# 4            Репродукция,Булшит,Беременность  Стесняюсь спросить
# ...                                      ...                 ...
# 30835                    Анализы,Диагностика   Ответили по науке
# 30836                                   Секс               Жизнь
# 30837                                   Кожа               Жизнь
# 30838                    Красота,Образ жизни   Ответили по науке
# 30839                                  Ногти              Разбор
#
# [25450 rows x 14 columns]

# %%
# оставляем только тех пользователей, у которых есть не слишком много и не слишком мало взаимодействий
def filter_for_iteration_range(df_raw, min=4, max=50):
    interaction_counts = df_raw.groupby('ehr_id')['article_id'].count()
    users_in_range = set(interaction_counts[(interaction_counts >= min) & (interaction_counts <= max)].index)
    df_filtered = data[data['ehr_id'].isin(users_in_range)]
    return df_filtered

# негерируем негативные сэмлы для работы модели
def generate_negative_samples(df, all_articles, n_negatives=3):
    negatives = []

    for user_id, group in df.groupby('ehr_id'):
        clicked = set(group['article_id'])
        not_clicked = list(all_articles - clicked)
        sampled = np.random.choice(not_clicked, size=n_negatives, replace=False)

        for art in sampled:
            negatives.append({
                "ehr_id": user_id,
                "article_id": art,
                "label": 0
            })

    return pd.DataFrame(negatives)

# %%
data = filter_for_iteration_range(data)
data
# Out:
#             id                article_id   ehr_id created_at  gender  age
# 44     3753815  60258f50e3c78375686c0c51  1132756 2023-07-01       1   48  \
# 51     3754559  62e24b5be4ff39162208fd33  1169819 2023-07-01       1   31
# 52     3754575  62e24b5be4ff39162208fd33  1169819 2023-07-01       1   31
# 53     3754576  62e24610a9c9279df00b8673  1169819 2023-07-01       1   31
# 54     3754581  62e0f1c5df18e4454c047292  1169819 2023-07-01       1   31
# ...        ...                       ...      ...        ...     ...  ...
# 30815  9603468  622b44d60e7b1e54fe5e5342   272451 2024-07-30       1   52
# 30816  9603700  6218dd9140e8460b6d1e326b    57714 2024-07-30       1   58
# 30817  9603737  617bfecbd4f2793d703e2db2  1145846 2024-07-30       1   36
# 30818  9603851  63e10773dbd23b1bff0b7002   263328 2024-07-30       1   31
# 30823  9606297  64d26487404f426d590b9d32  1420298 2024-07-30       1   40
#
#         birthday
# 44    1976-12-22  \
# 51    1993-07-08
# 52    1993-07-08
# 53    1993-07-08
# 54    1993-07-08
# ...          ...
# 30815 1973-01-09
# 30816 1966-06-25
# 30817 1989-05-11
# 30818 1993-09-13
# 30823 1985-01-28
#
#                                                                                           title
# 44                                                              ​Как понять, что у вас паразиты  \
# 51                                  Как скрининг помог вовремя обнаружить дисплазию шейки матки
# 52                                  Как скрининг помог вовремя обнаружить дисплазию шейки матки
# 53                            Что почитать: «Мальчик, который не переставал расти» Эдвина Кёрка
# 54     «В суете нашей жизни некогда подумать о собственном здоровье»: как предотвратить инсульт
# ...                                                                                         ...
# 30815                                                                     Cкрининг на рак груди
# 30816                                     Если хорошенько потрястись, это поможет снять стресс?
# 30817                              Одноразовые электронные сигареты опаснее, чем обычные вейпы?
# 30818                                         Плесень на орехах и кукурузе вызывает рак печени?
# 30823                                                                   Обрезание — это больно?
#
#                                                                              url
# 44               https://cuprum.media/science-answers/find-parasites?from=avaapp  \
# 51                https://cuprum.media/interview/neoplasia-screening?from=avaapp
# 52                https://cuprum.media/interview/neoplasia-screening?from=avaapp
# 53     https://cuprum.media/razbor/the-boy-who-never-stopped-growing?from=avaapp
# 54                  https://cuprum.media/interview/stroke-prevention?from=avaapp
# ...                                                                          ...
# 30815    https://cuprum.media/spravochnik/screening-breast-cancer-sp?from=avaapp
# 30816                https://cuprum.media/proverka-sluha/shaking-off?from=avaapp
# 30817                        https://cuprum.media/razbor/vape-nation?from=avaapp
# 30818           https://cuprum.media/science-answers/nuts-and-cancer?from=avaapp
# 30823                         https://cuprum.media/razbor/obrezaniye?from=avaapp
#
#          views published_date    formats                          tags
# 44      5779.0     2021-02-11   longread                             0  \
# 51      4580.0     2022-07-28  interview  Диагностика,Женское здоровье
# 52      4580.0     2022-07-28  interview  Диагностика,Женское здоровье
# 53       347.0     2022-07-28   longread                         Книги
# 54       892.0     2022-07-27  interview                   Диагностика
# ...        ...            ...        ...                           ...
# 30815   1072.0     2022-03-11  shortread                      Скрининг
# 30816   6086.0     2022-02-25   longread                    Ментальное
# 30817  11716.0     2021-10-29   longread                 Горло,Гаджеты
# 30818   1455.0     2023-02-06   longread        Еда,Онкология,Патогены
# 30823  26681.0     2023-08-08   longread             Деликатный вопрос
#
#             rubric_title
# 44     Ответили по науке
# 51              Интервью
# 52              Интервью
# 53                Разбор
# 54              Интервью
# ...                  ...
# 30815         Справочник
# 30816     Проверка слуха
# 30817             Разбор
# 30818  Ответили по науке
# 30823             Разбор
#
# [7482 rows x 14 columns]

# %%
## Разбиваем данные на тестовый и тренировочный сеты по времени, 80/20 процентов с разбивкой по времени
data = data.dropna(subset=['gender', 'rubric_title', 'tags', 'formats'])
data['label'] = 1
data['created_at'] = pd.to_datetime(data['created_at'])
data = data.sort_values("created_at")

cutoff_date = data['created_at'].quantile(0.8)
train_df = data[data['created_at'] <= cutoff_date]
test_df = data[data['created_at'] > cutoff_date]

data
# Out:
#             id                article_id   ehr_id created_at  gender  age
# 44     3753815  60258f50e3c78375686c0c51  1132756 2023-07-01       1   48  \
# 51     3754559  62e24b5be4ff39162208fd33  1169819 2023-07-01       1   31
# 52     3754575  62e24b5be4ff39162208fd33  1169819 2023-07-01       1   31
# 53     3754576  62e24610a9c9279df00b8673  1169819 2023-07-01       1   31
# 54     3754581  62e0f1c5df18e4454c047292  1169819 2023-07-01       1   31
# ...        ...                       ...      ...        ...     ...  ...
# 30818  9603851  63e10773dbd23b1bff0b7002   263328 2024-07-30       1   31
# 30814  9602975  62012efa3b61f04c0a2f2725  1049448 2024-07-30       1   33
# 30815  9603468  622b44d60e7b1e54fe5e5342   272451 2024-07-30       1   52
# 30816  9603700  6218dd9140e8460b6d1e326b    57714 2024-07-30       1   58
# 30823  9606297  64d26487404f426d590b9d32  1420298 2024-07-30       1   40
#
#         birthday
# 44    1976-12-22  \
# 51    1993-07-08
# 52    1993-07-08
# 53    1993-07-08
# 54    1993-07-08
# ...          ...
# 30818 1993-09-13
# 30814 1991-11-30
# 30815 1973-01-09
# 30816 1966-06-25
# 30823 1985-01-28
#
#                                                                                           title
# 44                                                              ​Как понять, что у вас паразиты  \
# 51                                  Как скрининг помог вовремя обнаружить дисплазию шейки матки
# 52                                  Как скрининг помог вовремя обнаружить дисплазию шейки матки
# 53                            Что почитать: «Мальчик, который не переставал расти» Эдвина Кёрка
# 54     «В суете нашей жизни некогда подумать о собственном здоровье»: как предотвратить инсульт
# ...                                                                                         ...
# 30818                                         Плесень на орехах и кукурузе вызывает рак печени?
# 30814                                   Может ли у грибов развиваться устойчивость к лекарствам
# 30815                                                                     Cкрининг на рак груди
# 30816                                     Если хорошенько потрястись, это поможет снять стресс?
# 30823                                                                   Обрезание — это больно?
#
#                                                                              url
# 44               https://cuprum.media/science-answers/find-parasites?from=avaapp  \
# 51                https://cuprum.media/interview/neoplasia-screening?from=avaapp
# 52                https://cuprum.media/interview/neoplasia-screening?from=avaapp
# 53     https://cuprum.media/razbor/the-boy-who-never-stopped-growing?from=avaapp
# 54                  https://cuprum.media/interview/stroke-prevention?from=avaapp
# ...                                                                          ...
# 30818           https://cuprum.media/science-answers/nuts-and-cancer?from=avaapp
# 30814      https://cuprum.media/proverka-sluha/antifungal-resistance?from=avaapp
# 30815    https://cuprum.media/spravochnik/screening-breast-cancer-sp?from=avaapp
# 30816                https://cuprum.media/proverka-sluha/shaking-off?from=avaapp
# 30823                         https://cuprum.media/razbor/obrezaniye?from=avaapp
#
#          views published_date    formats                          tags
# 44      5779.0     2021-02-11   longread                             0  \
# 51      4580.0     2022-07-28  interview  Диагностика,Женское здоровье
# 52      4580.0     2022-07-28  interview  Диагностика,Женское здоровье
# 53       347.0     2022-07-28   longread                         Книги
# 54       892.0     2022-07-27  interview                   Диагностика
# ...        ...            ...        ...                           ...
# 30818   1455.0     2023-02-06   longread        Еда,Онкология,Патогены
# 30814   2686.0     2022-02-07   longread                         Наука
# 30815   1072.0     2022-03-11  shortread                      Скрининг
# 30816   6086.0     2022-02-25   longread                    Ментальное
# 30823  26681.0     2023-08-08   longread             Деликатный вопрос
#
#             rubric_title  label
# 44     Ответили по науке      1
# 51              Интервью      1
# 52              Интервью      1
# 53                Разбор      1
# 54              Интервью      1
# ...                  ...    ...
# 30818  Ответили по науке      1
# 30814     Проверка слуха      1
# 30815         Справочник      1
# 30816     Проверка слуха      1
# 30823             Разбор      1
#
# [7428 rows x 15 columns]

# %%
all_articles = set(data['article_id'].unique())

train_neg = generate_negative_samples(train_df, all_articles, n_negatives=20)
train_pos = train_df.copy()
train_pos['label'] = 1

# Нужно добавить article-фичи к негативным:
article_features = data.drop_duplicates('article_id')[
    ['article_id', 'rubric_title', 'tags', 'formats', 'views']
]

train_neg = train_neg.merge(article_features, on='article_id', how='left')

# И добавить user-фичи (gender, age):
user_features = data.drop_duplicates('ehr_id')[['ehr_id', 'gender', 'age']]
train_neg = train_neg.merge(user_features, on='ehr_id', how='left')

# Объединяем:
train_df_full = pd.concat([train_pos, train_neg], ignore_index=True)

# %%
features = ['gender', 'age', 'rubric_title', 'tags', 'formats', 'views']
cat_features = ['gender', 'rubric_title', 'tags', 'formats']

train_df_full = train_df_full.sort_values("ehr_id")
group_sizes = train_df_full.groupby('ehr_id').size().values

train_pool = Pool(
    data=train_df_full[features],
    label=train_df_full['label'],
    group_id=train_df_full['ehr_id'],
    cat_features=cat_features
)

model = CatBoostRanker(iterations=300, learning_rate=0.1, depth=6, verbose=50)
model.fit(train_pool)
# Out:
# Groupwise loss function. OneHotMaxSize set to 10
# 0:	total: 125ms	remaining: 37.2s
# 50:	total: 1.99s	remaining: 9.72s
# 100:	total: 3.8s	remaining: 7.48s
# 150:	total: 5.64s	remaining: 5.57s
# 200:	total: 7.49s	remaining: 3.69s
# 250:	total: 9.32s	remaining: 1.82s
# 299:	total: 11.2s	remaining: 0us

# %%
# 1. Повторно получаем список всех статей
all_articles = set(data['article_id'].unique())

# 2. Генерируем негативные примеры
test_neg = generate_negative_samples(test_df, all_articles, n_negatives=20)

# 3. Метка для позитивных примеров
test_pos = test_df.copy()
test_pos['label'] = 1

# 4. Добавляем признаки к негативам
test_neg = test_neg.merge(article_features, on='article_id', how='left')
test_neg = test_neg.merge(user_features, on='ehr_id', how='left')

# 5. Объединяем позитивные и негативные примеры
test_df_full = pd.concat([test_pos, test_neg], ignore_index=True)

# 6. Создаём test_pool
test_df_full = test_df_full.sort_values("ehr_id")

test_pool = Pool(
    data=test_df_full[features],
    label=test_df_full['label'],
    group_id=test_df_full['ehr_id'],
    cat_features=cat_features
)

# %%
test_df_full['prediction'] = model.predict(test_pool)

# %%
def hit_rate_at_k(df, k=5):
    hits = 0
    total_users = 0

    for user, group in df.groupby('ehr_id'):
        top_k = group.sort_values('prediction', ascending=False).head(k)
        if (top_k['label'] == 1).any():
            hits += 1
        total_users += 1

    return hits / total_users

# %%
hr5 = hit_rate_at_k(test_df_full, k=5)
print(f"HitRate@5: {hr5:.4f}")
# Out:
# HitRate@5: 0.5234

# %%
import numpy as np

def mrr_at_k(df, k=5):
    mrr_total = 0.0
    user_count = 0

    for _, group in df.groupby('ehr_id'):
        group_sorted = group.sort_values('prediction', ascending=False).head(k)
        relevance = group_sorted['label'].values

        # Find the rank of the first relevant item
        for rank, rel in enumerate(relevance, start=1):
            if rel == 1:
                mrr_total += 1.0 / rank
                break
        user_count += 1

    return mrr_total / user_count if user_count > 0 else 0.0


def ndcg_at_k(df, k=5):
    ndcg_total = 0.0
    user_count = 0

    for _, group in df.groupby('ehr_id'):
        group_sorted = group.sort_values('prediction', ascending=False).head(k)
        relevance = group_sorted['label'].values

        dcg = 0.0
        for i, rel in enumerate(relevance):
            dcg += (2**rel - 1) / np.log2(i + 2)

        ideal_relevance = sorted(relevance, reverse=True)
        idcg = 0.0
        for i, rel in enumerate(ideal_relevance):
            idcg += (2**rel - 1) / np.log2(i + 2)

        if idcg > 0:
            ndcg_total += dcg / idcg
        else:
            ndcg_total += 0.0

        user_count += 1

    return ndcg_total / user_count if user_count > 0 else 0.0

# %%
mrr5 = mrr_at_k(test_df_full, k=5)
ndcg5 = ndcg_at_k(test_df_full, k=5)

print(f"MRR@5: {mrr5:.4f}")
print(f"NDCG@5: {ndcg5:.4f}")
# Out:
# MRR@5: 0.3001
# NDCG@5: 0.3541

# %%
from catboost import CatBoostRanker, Pool

features = ['gender', 'age', 'rubric_title', 'tags', 'formats', 'views']
cat_features = ['gender', 'rubric_title', 'tags', 'formats']

#data = data.dropna(subset=['gender', 'rubric_title', 'tags', 'formats'])

# Удаляем строки с NaN в категориальных признаках
train_df = train_df.dropna(subset=cat_features)

# Приводим категориальные признаки к строке
for col in cat_features:
    train_df[col] = train_df[col].astype(str)

# Сортировка по group_id (обязательно для CatBoostRanker)
train_df = train_df.sort_values('ehr_id')


train_pool = Pool(data=train_df[features],
                  label=train_df['label'],
                  group_id=train_df['ehr_id'],
                  cat_features=cat_features)

model = CatBoostRanker(iterations=300, learning_rate=0.1, depth=6, verbose=50)
model.fit(train_pool)
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In[14], line 25
#      19 train_pool = Pool(data=train_df[features],
#      20                   label=train_df['label'],
#      21                   group_id=train_df['ehr_id'],
#      22                   cat_features=cat_features)
#      24 model = CatBoostRanker(iterations=300, learning_rate=0.1, depth=6, verbose=50)
# ---> 25 model.fit(train_pool)
#
# File ~/sgm_recsys/.venv_sgm_recsys/lib/python3.10/site-packages/catboost/core.py:6099, in CatBoostRanker.fit(self, X, y, group_id, cat_features, text_features, embedding_features, pairs, sample_weight, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    6096 if 'loss_function' in params:
#    6097     CatBoostRanker._check_is_compatible_loss(params['loss_function'])
# -> 6099 self._fit(X, y, cat_features, text_features, embedding_features, pairs,
#    6100           sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model,
#    6101           eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    6102           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    6103 return self
#
# File ~/sgm_recsys/.venv_sgm_recsys/lib/python3.10/site-packages/catboost/core.py:2319, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2315 allow_clear_pool = train_params["allow_clear_pool"]
#    2317 with log_fixup(log_cout, log_cerr), \
#    2318     plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2319     self._train(
#    2320         train_pool,
#    2321         train_params["eval_sets"],
#    2322         params,
#    2323         allow_clear_pool,
#    2324         train_params["init_model"]
#    2325     )
#    2327 # Have property feature_importance possibly set
#    2328 loss = self._object._get_loss_function_name()
#
# File ~/sgm_recsys/.venv_sgm_recsys/lib/python3.10/site-packages/catboost/core.py:1723, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1722 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1723     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1724     self._set_trained_model_attributes()
#
# File _catboost.pyx:4645, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4694, in _catboost._CatBoost._train()
#
# CatBoostError: /src/catboost/catboost/libs/metrics/metric.cpp:6526: All train targets are equal

# %%
train_df
# Out:
#             id                article_id   ehr_id created_at gender  age
# 18497  6801107  624da036b341c600db685964     3670 2024-01-25      1   54  \
# 18498  6801131  624dc403d6fbe97b384ccc22     3670 2024-01-25      1   54
# 11258  5439270  60f57272c17ff86423582032     3670 2023-10-25      1   54
# 11259  5439299  60f6e195a9e57f28ce4194b3     3670 2023-10-25      1   54
# 18470  6794430  61039e8a65fa090ddd554472     3670 2024-01-25      1   54
# ...        ...                       ...      ...        ...    ...  ...
# 23829  7927581  625991995319175a274b95f3  1396493 2024-04-05      2   24
# 23839  7929756  625834f2879bd209ac6e1123  1396493 2024-04-05      2   24
# 23830  7927589  6258368f56efd0745c2cd364  1396493 2024-04-05      2   24
# 24015  7974349  5f918991b2b1e5081913df51  1396802 2024-04-08      1   44
# 24016  7974361  5f9291ba5107d0594e44c171  1396802 2024-04-08      1   44
#
#         birthday
# 18497 1970-09-07  \
# 18498 1970-09-07
# 11258 1970-09-07
# 11259 1970-09-07
# 18470 1970-09-07
# ...          ...
# 23829 2000-11-04
# 23839 2000-11-04
# 23830 2000-11-04
# 24015 1981-06-14
# 24016 1981-06-14
#
#                                                                                                   title
# 18497                                                     Почему ребенок всегда просит макароны с сыром  \
# 18498                                                               Есть ли толк от очистителей воздуха
# 11258                                                    Правда, что картошка — самый бесполезный овощ?
# 11259                                                              Как поговорить с бабушкой о здоровье
# 18470                                                                            B12 и фолиевая кислота
# ...                                                                                                 ...
# 23829                                                                      Как еда влияет на настроение
# 23839                                           Что происходит с моими руками, пока я залипаю в телефон
# 23830  Кто-то взорвал бочку с азотной кислотой и есть риск, что облако путешествует. Это правда опасно?
# 24015                                                  Ночная потливость Ричарда из «Кремниевой долины»
# 24016                                                                  Кофейные клизмы помогут от рака?
#
#                                                                              url
# 18497                    https://cuprum.media/columns/pasta-and-kids?from=avaapp  \
# 18498  https://cuprum.media/proverka-sluha/air-purifiers-work-or-not?from=avaapp
# 11258     https://cuprum.media/proverka-sluha/potato-are-not-villain?from=avaapp
# 11259               https://cuprum.media/razbor/stubborn-grandmother?from=avaapp
# 18470       https://cuprum.media/spravochnik/b12-i-folievaya-kislota?from=avaapp
# ...                                                                          ...
# 23829                     https://cuprum.media/razbor/good-mood-food?from=avaapp
# 23839                     https://cuprum.media/ipohondrik/hand-phone?from=avaapp
# 23830          https://cuprum.media/proverka-sluha/nitric-acid-cloud?from=avaapp
# 24015                       https://cuprum.media/razbor/night-sweats?from=avaapp
# 24016                  https://cuprum.media/proverka-sluha/starbutts?from=avaapp
#
#         views published_date    formats
# 18497  3358.0     2022-04-06  interview  \
# 18498  1797.0     2022-04-06   longread
# 11258  6682.0     2021-07-19   longread
# 11259  2796.0     2021-07-20   longread
# 18470  2269.0     2021-07-31  shortread
# ...       ...            ...        ...
# 23829  3792.0     2022-04-15   longread
# 23839  8140.0     2022-04-14   longread
# 23830  2009.0     2022-04-14   longread
# 24015  1017.0     2020-10-22   longread
# 24016  3932.0     2020-10-23   longread
#
#                                                     tags    rubric_title
# 18497                                            Питание     Блог врачей  \
# 18498                                   Экология,Вредное  Проверка слуха
# 11258                                                Еда  Проверка слуха
# 11259  Взрослеем как взрослые,Старший возраст,Спецпроект          Разбор
# 18470                                       Обследования      Справочник
# ...                                                  ...             ...
# 23829                                            Питание          Разбор
# 23839                                       Суставы,Руки      Ипохондрик
# 23830                               Вредное,Яд ,Экология  Проверка слуха
# 24015                                     Сон,Ментальное          Разбор
# 24016                                   Булшит,Онкология  Проверка слуха
#
#        label
# 18497      1
# 18498      1
# 11258      1
# 11259      1
# 18470      1
# ...      ...
# 23829      1
# 23839      1
# 23830      1
# 24015      1
# 24016      1
#
# [5947 rows x 15 columns]

# %%
train_articles = set(train_df['article_id'])
test_articles = set(test_df['article_id'])

only_in_test = test_articles - train_articles
print(f"Новых статей в тесте: {len(only_in_test)}")
# Out:
# Новых статей в тесте: 316

# %%
article_feats_ids = set(article_features['article_id'])
missing = only_in_test - article_feats_ids
print(f"Статей без фичей: {len(missing)}")  # желательно 0
# Out:
# Статей без фичей: 0
